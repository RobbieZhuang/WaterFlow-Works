# %%
import requests
import json
import pickle

from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# %%
def g(url):
    
    with requests.Session() as s:
        retries = Retry(total=10, backoff_factor=1, status_forcelist=[500, 502, 503, 504])

        s.mount('http://', HTTPAdapter(max_retries=retries))
        s.mount('https://', HTTPAdapter(max_retries=retries))

        return s.get(url, timeout=10)

# %%
sqlstr = lambda string: "'" + str(string).replace("'", "''") + "'"

# %% [markdown]
# ### Results

# %%
## SQL create statements
stmts_faculty = []
stmts_degree = []
stmts_subject = []
stmts_course = []
stmts_courseGroup = []
stmts_courseGroupMember = []
stmts_prerequisite = []
stmts_degreeRequirement = []
stmts_term = []
stmts_courseOffering = []
stmts_ratemyprofs = []

# %%
## Entity Sets for Later Use
set_faculty = set()
set_subject = set()
set_course = set()
set_courseOffering = set()
set_ratemyprofs = set()

# %% [markdown]
# ### Term

# %%
## strings for terms
terms = [str(100 + y) + str(t) for y in range (13, 21) for t in [1, 5, 9]]

# %%
stmts_term = [f'INSERT INTO term (code) VALUES ({term});' for term in terms]

# %% [markdown]
# ### Faculty

# %%
with open('faculty.json', 'r') as faculty_f:
    faculties = json.load(faculty_f)

# %%
set_faculty = set()
stmts_faculty = []

for faculty in faculties:
    title = faculty['group_code']
    short_name = faculty['group_short_name']
    full_name = faculty['group_full_name']
    
    set_faculty.add(title)
    stmts_faculty.append(
        "INSERT INTO faculty (title, shortName, fullName) VALUES (%s, %s, %s);" % 
        (sqlstr(title), sqlstr(short_name), sqlstr(full_name))
    )

# %% [markdown]
# ### Subject

# %%
with open('subject.json', 'r') as subject_f:
  subjects = json.load(subject_f)

# %%
set_subject = set()
stmts_subject = []

for subject in subjects:
    title = subject['subject']
    desc = subject['description']
    faculty = subject['group']
    
    if faculty in set_faculty:
        set_subject.add(title)
        stmts_subject.append(
            "INSERT INTO subject (title, facultyTitle, description) VALUES (%s, %s, %s);" % 
            (sqlstr(title), sqlstr(faculty), sqlstr(desc))
        )

# %% [markdown]
# ### Courses

# %% [markdown]
# #### You can import the courses from `course.txt` if the file exists.

# %%
# set_course = set()
# with open('course.txt', 'r') as f:
#     for line in f:
#         set_course.add(line.strip())

# %% [markdown]
# #### Alternatively, you can scrape the course data from the OpenAPI as well.

# %%
courses_r = g('https://api.uwaterloo.ca/v2/courses.json?key=e5c5ea41b7715202b2846b04b286f29d')
courses = list(filter(lambda c: '`' not in c['catalog_number'], courses_r.json()['data'])) # there is a "GER 744`"

# %%
set_course = set()
stmts_course = []

l = len(courses)

for i, c in enumerate(courses):
    subject_title = c['subject']
    catalog_number = c['catalog_number']
    
    course_code = subject_title + ' ' + catalog_number
    
    ## print the progress of processing
    print('%s/%s course(s) processed. Processing %s.\t\t' % (i, l, course_code), end='\r', flush=True)

    course_detail_r = g(
        'https://api.uwaterloo.ca/v2/courses/%s/%s.json?key=e5c5ea41b7715202b2846b04b286f29d' %
        (subject_title, catalog_number)
    ).json()

    if 'data' in course_detail_r and course_detail_r['data'] and subject_title in set_subject:
        course_detail = course_detail_r['data']

        title = course_detail['title']
        credit = course_detail['units']
        desc = course_detail['description']
        course_types = ', '.join(ins for ins in course_detail['instructions'])

        set_course.add(course_code)
        stmts_course.append(
            "INSERT INTO course (courseCode, title, credit, courseTypes, description, subjectTitle) VALUES (%s, %s, %s, %s, %s, %s);" %
            (sqlstr(course_code),
             sqlstr(title),
             credit,
             sqlstr(course_types),
             sqlstr(desc),
             sqlstr(subject_title))
        )
        
print('\ndone.')
# Out:
# 7448/7449 course(s) processed. Processing SYDE 263.				k.
# done.

# %% [markdown]
# ### Course Offerings

# %%
set_courseOffering = set()
stmts_courseOffering = []

l = len(set_subject)
l_terms = len(terms)

for i, subject_title in enumerate(set_subject):
    
    for j, term in enumerate(terms):
        
        ## print the progress of processing
        print('%s/%s terms out of %s/%s subject(s) processed. Processing term=%s, subject=%s. So far %s offering(s) recorded.\t\t' %
              (j, l_terms, i, l, term, subject_title, len(stmts_courseOffering)), end='\r', flush=True)
            
        offerings_r = g(
            'https://api.uwaterloo.ca/v2/terms/%s/%s/schedule.json?key=e5c5ea41b7715202b2846b04b286f29d' %
            (term, subject_title)
        ).json()
                
        if 'data' in offerings_r and offerings_r['data']:
            offerings = offerings_r['data']

            for offering in offerings:
                catalog_number = offering['catalog_number']
                course_code = subject_title + ' ' + catalog_number

                if course_code in set_course:
                    args = []
                    vals = []

                    args.append('courseCode')
                    vals.append(sqlstr(course_code))

                    args.append('termCode')
                    vals.append(term)

                    section = offering['section'].split(' ')

                    courseType = section[0]
                    component = section[1]
                    
                    if (course_code, term, component) not in set_courseOffering:
                        args.append('courseType')
                        vals.append(sqlstr(courseType))

                        args.append('component')
                        vals.append(component)

                        if offering['related_component_1']:
                            args.append('relatedComponent1')
                            vals.append(str(offering['related_component_1']))

                        if offering['related_component_2']:
                            args.append('relatedComponent2')
                            vals.append(str(offering['related_component_2']))

                        enrlCap = offering['enrollment_capacity']
                        enrlTot = offering['enrollment_total']

                        args.append('enrlCap')
                        vals.append(str(enrlCap))

                        args.append('enrlTot')
                        vals.append(str(enrlTot))

                        classes = offering['classes']
                        if classes:
                            cls = classes[0]
                            
                            clsDate = cls['date']
                            if clsDate:
                                if clsDate['is_cancelled'] == True:
                                    continue
                                    
                                if clsDate['start_time']:
                                    args.append('classStartTime')
                                    vals.append(sqlstr(clsDate['start_time']))

                                if clsDate['end_time']:
                                    args.append('classEndTime')
                                    vals.append(sqlstr(clsDate['end_time']))

                                if clsDate['weekdays']:
                                    args.append('classWeekdays')
                                    vals.append(sqlstr(clsDate['weekdays']))

                            instructors = cls['instructors']
                            if instructors:
                                prof = instructors[0].split(',')

                                if len(prof) > 1:
                                    args.append('profFirstName')
                                    vals.append(sqlstr(prof[1]))

                                args.append('profLastName')
                                vals.append(sqlstr(prof[0]))

                            loc = cls['location']
                            if loc:
                                if loc['building']:
                                    args.append('classBuilding')
                                    vals.append(sqlstr(loc['building']))

                                if loc['room']:
                                    args.append('classRoom')
                                    vals.append(sqlstr(loc['room']))

                        set_courseOffering.add((course_code, term, component))
                        stmts_courseOffering.append(
                            f"INSERT INTO courseOffering ({', '.join(args)}) VALUES ({', '.join(vals)});"
                        )
                    
print('\ndone.')
# Out:
# 1/33 terms out of 1/207 subject(s) processed. Processing term=1205, subject=STAT. So far 0 offering(s) recorded.
# done.

# %% [markdown]
# ### Course Prereqs

# %%
prereq_endpoint = "https://api.uwaterloo.ca/v2/courses/{}/{}/prerequisites.json?key=e5c5ea41b7715202b2846b04b286f29d&fbclid=IwAR26szkbPavfEMNVDdLaYTznyHkCz8imaQ7PrAd8fUmG2WSjXJiew6kuFsw"

for i, course in enumerate(courses):
    subject = course['subject']
    num = course['catalog_number']
    
    course['prerequisites_parsed'] = []
    course_endpoint = prereq_endpoint.format(subject, num)
    
    print("Finding prereqs for {} {} ({}/{}) \t\t".format(subject, num, i, len(courses)), end="\r", flush=True)
    
    r = g(course_endpoint)
    while r.status_code != 200:
        # Test for request error
        print("ERROR!")
        r = g(course_endpoint)
        
    info = r.json()
    status = info['meta']['status']
    
    # Test for API error
    if status == 204:
        # No data returned
        continue
    elif status == 200: 
        # Found prereqs
        if "data" in info:
            course['prerequisites_parsed'] = info['data']['prerequisites_parsed']
    else:
        print("ERROR: got status {}".format(info['status']))
        
print('\ndone.')
# Out:
# Finding prereqs for SYDE 263 (7448/7449) 				)
# done.

# %%
# Save them just in case the next step messes them up
pickle.dump(courses, open("courses_with_prereqs.pckl", "wb"))

# %%
def formatCourseName(s):
    """
    CS135 -> CS 135
    """
    split_idx = 0
    for i in range(len(s)):
        if s[i].isdigit():
            break
        split_idx += 1
    return s[:split_idx] + " " + s[split_idx:]

assert formatCourseName("CS135") == "CS 135"
assert formatCourseName("MECH223") == "MECH 223"

# %%
def flattenORPrereqs(lst):
    # I think I did too much racket programming guys... #foldr
    
    if len(lst) == 0:
        return []
    elif lst[0] == 1:
        return [1] + flattenORPrereqs(lst[1:])
    elif isinstance(lst[0], list) and lst[0][0] == 1:
        return flattenORPrereqs(lst[0][1:]) + flattenORPrereqs(lst[1:])
    elif isinstance(lst[0], list):
        return flattenORPrereqs(lst[0]) + flattenORPrereqs(lst[1:])
    else:
        return [lst[0]] + flattenORPrereqs(lst[1:])
            
    
bad_input = [1, [1, 'AFM372', 'ACTSC391'], ['ACTSC231', 'ACTSC371'], 'ACTSC231BUS']
expected = [1, 'AFM372', 'ACTSC391', 'ACTSC231', 'ACTSC371', 'ACTSC231BUS']
assert flattenORPrereqs(bad_input) == expected

# %%
from collections import defaultdict

prereq_mapping = defaultdict(list)

for course in courses:
    course_name = course['subject'] + " " + course['catalog_number']
    prereqs = course['prerequisites_parsed']
    if prereqs is None:
        continue
    if len(prereqs) > 0 and isinstance(prereqs[0], int):
        prereqs = [prereqs]
    
    for pre in prereqs:
        if isinstance(pre, list) and len(pre) > 1:
            pre = flattenORPrereqs(pre)
            orCount = pre[0]
            pre[0] = 1 # Some, like FRENCH, will have 2. Just make it one for simplicity...
            # Make a course group
            course_group = []
            for c in pre[1:]:
                g = formatCourseName(c)
                course_group.append(g)
            course_group = list(map(formatCourseName, pre[1:]))
            course_group = list(filter(lambda c: c in set_course, course_group))
            if len(course_group) == 0:
                continue
            prereq_mapping[course_name].append((orCount, course_group))
        else:
            # A single required course
            try:
                c = formatCourseName(pre)
                if c in set_course:
                    prereq_mapping[course_name].append((1, [c])) # 1 OR count -> That course is mandatory
            except:
                # Probably an error with the UW API
                continue
        
        ### DEBUG ###
        #if len(prereq_mapping[course_id]) > 0:
        #    print(prereq_mapping[course_id][-1])

# %%
# This is just a sanity check to make sure all the courses and their prereqs are in `set_course`
for k, v in prereq_mapping.items():
    if k not in set_course:
        print(k, v)
        raise Exception("{} is not in `set_course`, make some deletions!")
        break
    for l in v:
        for p in l[1]:
            if p not in set_course:
                raise Exception("{} is not in `set_course`, make some deletions!".format(p))

# %%
# Create a course group
courseGroupQuery = """INSERT INTO courseGroup (quantity) VALUES ({});"""
courseGroupMemberQuery = """
WITH groupID as(
    SELECT currval(pg_get_serial_sequence('courseGroup', 'groupid')) as v
)
INSERT INTO courseGroupMember (courseCode, courseGroupID) VALUES ('{}', (SELECT v from groupID));"""

# Add a course group as a prereq
addPrereqQuery = """
WITH groupID as(
    SELECT currval(pg_get_serial_sequence('courseGroup', 'groupid')) as v
)
INSERT INTO prerequisite (courseCode, prereqCourseGroupID) VALUES ('{}', (SELECT v from groupID));
"""

# %%
stmts_prerequisite = []

for course, prereqs in prereq_mapping.items():
    
    # Comments for the insert file
    stmts_prerequisite.append( "-" * 100)
    stmts_prerequisite.append( "--- {} --> {}".format(course, prereqs))
    stmts_prerequisite.append( "-" * 100)
    
    for num_required_from_or, or_prereq_lst in prereqs:
 
        stmts_prerequisite.append( courseGroupQuery.format( num_required_from_or ) )
            
        or_prereq_lst = list(set(or_prereq_lst))
        for p in or_prereq_lst:
            stmts_prerequisite.append( courseGroupMemberQuery.format(p) )
        
        stmts_prerequisite.append( addPrereqQuery.format(course))

# %% [markdown]
# ## RateMyProf Data

# %%
with open('profs.json', 'r') as profs_f:
  profs = json.load(profs_f)['response']['docs']

# %%
profs
# Out:
# [{'averageratingscore_rf': 4.33,
#   'pk_id': 9845,
#   'total_number_of_ratings_i': 564,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Larry',
#   'teacherlastname_t': 'Smith'},
#  {'averageratingscore_rf': 4.15,
#   'pk_id': 21566,
#   'total_number_of_ratings_i': 340,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Firas',
#   'teacherlastname_t': 'Mansour'},
#  {'averageratingscore_rf': 4.5,
#   'pk_id': 15411,
#   'total_number_of_ratings_i': 318,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Richard',
#   'teacherlastname_t': 'Ennis'},
#  {'averageratingscore_rf': 4.63,
#   'pk_id': 10138,
#   'total_number_of_ratings_i': 261,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Ehab',
#   'teacherlastname_t': 'El-Saadany'},
#  {'averageratingscore_rf': 4.45,
#   'pk_id': 10102,
#   'total_number_of_ratings_i': 255,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Carey',
#   'teacherlastname_t': 'Bissonnette'},
#  {'averageratingscore_rf': 2.43,
#   'pk_id': 10087,
#   'total_number_of_ratings_i': 254,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Eva',
#   'teacherlastname_t': 'Lau'},
#  {'averageratingscore_rf': 4.5,
#   'pk_id': 8944,
#   'total_number_of_ratings_i': 235,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Troy',
#   'teacherlastname_t': 'Vasiga'},
#  {'averageratingscore_rf': 2.51,
#   'pk_id': 10483,
#   'total_number_of_ratings_i': 233,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Bob',
#   'teacherlastname_t': 'Sproule'},
#  {'averageratingscore_rf': 4.0,
#   'pk_id': 7556,
#   'total_number_of_ratings_i': 222,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Chris',
#   'teacherlastname_t': 'Burris'},
#  {'averageratingscore_rf': 1.67,
#   'pk_id': 9794,
#   'total_number_of_ratings_i': 210,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'James A (Jim)',
#   'teacherlastname_t': 'Barby'},
#  {'averageratingscore_rf': 4.8,
#   'pk_id': 1561192,
#   'total_number_of_ratings_i': 210,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Richard',
#   'teacherlastname_t': 'Marta'},
#  {'averageratingscore_rf': 3.6,
#   'pk_id': 10085,
#   'total_number_of_ratings_i': 202,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Maryann',
#   'teacherlastname_t': 'Vaughan'},
#  {'averageratingscore_rf': 4.8,
#   'pk_id': 10242,
#   'total_number_of_ratings_i': 192,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Ian',
#   'teacherlastname_t': 'Vanderburgh'},
#  {'averageratingscore_rf': 4.7,
#   'pk_id': 10101,
#   'total_number_of_ratings_i': 178,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Stephen',
#   'teacherlastname_t': 'New'},
#  {'averageratingscore_rf': 4.8,
#   'pk_id': 16557,
#   'total_number_of_ratings_i': 167,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Rohan',
#   'teacherlastname_t': 'Jayasundera'},
#  {'averageratingscore_rf': 4.8,
#   'pk_id': 439053,
#   'total_number_of_ratings_i': 167,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Dan',
#   'teacherlastname_t': 'Wolczuk'},
#  {'averageratingscore_rf': 2.33,
#   'pk_id': 44377,
#   'total_number_of_ratings_i': 163,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Chris',
#   'teacherlastname_t': "O'Donovan"},
#  {'averageratingscore_rf': 4.7,
#   'pk_id': 10088,
#   'total_number_of_ratings_i': 160,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Emanuel',
#   'teacherlastname_t': 'Carvalho'},
#  {'averageratingscore_rf': 3.57,
#   'pk_id': 283950,
#   'total_number_of_ratings_i': 159,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Christine',
#   'teacherlastname_t': 'Dupont'},
#  {'averageratingscore_rf': 4.2,
#   'pk_id': 9998,
#   'total_number_of_ratings_i': 154,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Conrad',
#   'teacherlastname_t': 'Hewitt'},
#  {'averageratingscore_rf': 4.5,
#   'pk_id': 10046,
#   'total_number_of_ratings_i': 148,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'John-Paul',
#   'teacherlastname_t': 'Pretti'},
#  {'averageratingscore_rf': 2.5,
#   'pk_id': 10095,
#   'total_number_of_ratings_i': 145,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Keith',
#   'teacherlastname_t': 'Freeland'},
#  {'averageratingscore_rf': 4.0,
#   'pk_id': 10118,
#   'total_number_of_ratings_i': 142,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Steve',
#   'teacherlastname_t': 'Forsey'},
#  {'averageratingscore_rf': 3.43,
#   'pk_id': 334064,
#   'total_number_of_ratings_i': 141,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Riley',
#   'teacherlastname_t': 'Metzger'},
#  {'averageratingscore_rf': 4.8,
#   'pk_id': 10083,
#   'total_number_of_ratings_i': 140,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Serge',
#   'teacherlastname_t': "D'Alessio"},
#  {'averageratingscore_rf': 2.5,
#   'pk_id': 30097,
#   'total_number_of_ratings_i': 138,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Cheryl',
#   'teacherlastname_t': 'Duxbury'},
#  {'averageratingscore_rf': 4.34,
#   'pk_id': 17489,
#   'total_number_of_ratings_i': 135,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Niels C',
#   'teacherlastname_t': 'Bols'},
#  {'averageratingscore_rf': 2.3,
#   'pk_id': 779375,
#   'total_number_of_ratings_i': 135,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Mikko',
#   'teacherlastname_t': 'Packalen'},
#  {'averageratingscore_rf': 4.8,
#   'pk_id': 1948050,
#   'total_number_of_ratings_i': 134,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Jordan',
#   'teacherlastname_t': 'Hamilton'},
#  {'averageratingscore_rf': 3.0,
#   'pk_id': 11693,
#   'total_number_of_ratings_i': 131,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Steve',
#   'teacherlastname_t': 'Spencer'},
#  {'averageratingscore_rf': 4.49,
#   'pk_id': 16981,
#   'total_number_of_ratings_i': 131,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Brian',
#   'teacherlastname_t': 'Orend'},
#  {'averageratingscore_rf': 3.11,
#   'pk_id': 27862,
#   'total_number_of_ratings_i': 127,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'John',
#   'teacherlastname_t': 'North'},
#  {'averageratingscore_rf': 3.6,
#   'pk_id': 27289,
#   'total_number_of_ratings_i': 127,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Addie',
#   'teacherlastname_t': 'Nelson'},
#  {'averageratingscore_rf': 3.2,
#   'pk_id': 12636,
#   'total_number_of_ratings_i': 123,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Geoff',
#   'teacherlastname_t': 'Malleck'},
#  {'averageratingscore_rf': 3.7,
#   'pk_id': 14460,
#   'total_number_of_ratings_i': 123,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Joseph',
#   'teacherlastname_t': 'Dejuan'},
#  {'averageratingscore_rf': 2.4,
#   'pk_id': 10536,
#   'total_number_of_ratings_i': 122,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Sandy',
#   'teacherlastname_t': 'Graham'},
#  {'averageratingscore_rf': 2.34,
#   'pk_id': 43030,
#   'total_number_of_ratings_i': 121,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Lutz-Alexander',
#   'teacherlastname_t': 'Busch'},
#  {'averageratingscore_rf': 3.52,
#   'pk_id': 23723,
#   'total_number_of_ratings_i': 121,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Dragana',
#   'teacherlastname_t': 'Miskovic'},
#  {'averageratingscore_rf': 3.1,
#   'pk_id': 161608,
#   'total_number_of_ratings_i': 121,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Douglas',
#   'teacherlastname_t': 'Harder'},
#  {'averageratingscore_rf': 3.3,
#   'pk_id': 11996,
#   'total_number_of_ratings_i': 118,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Byron',
#   'teacherlastname_t': 'Becker'},
#  {'averageratingscore_rf': 3.1,
#   'pk_id': 10001,
#   'total_number_of_ratings_i': 117,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Cyntha',
#   'teacherlastname_t': 'Struthers'},
#  {'averageratingscore_rf': 2.45,
#   'pk_id': 14025,
#   'total_number_of_ratings_i': 117,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Kathryn',
#   'teacherlastname_t': 'McArthur'},
#  {'averageratingscore_rf': 4.3,
#   'pk_id': 96601,
#   'total_number_of_ratings_i': 116,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Fred',
#   'teacherlastname_t': 'Desroches'},
#  {'averageratingscore_rf': 3.56,
#   'pk_id': 11516,
#   'total_number_of_ratings_i': 115,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'B',
#   'teacherlastname_t': 'Rye'},
#  {'averageratingscore_rf': 4.3,
#   'pk_id': 10003,
#   'total_number_of_ratings_i': 114,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'R. P. J.',
#   'teacherlastname_t': 'André'},
#  {'averageratingscore_rf': 2.93,
#   'pk_id': 11077,
#   'total_number_of_ratings_i': 114,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Barry',
#   'teacherlastname_t': 'McClinchey'},
#  {'averageratingscore_rf': 4.94,
#   'pk_id': 1992386,
#   'total_number_of_ratings_i': 113,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Brenda',
#   'teacherlastname_t': 'Lee'},
#  {'averageratingscore_rf': 3.8,
#   'pk_id': 10000,
#   'total_number_of_ratings_i': 112,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Prabhakar',
#   'teacherlastname_t': 'Ragde'},
#  {'averageratingscore_rf': 2.12,
#   'pk_id': 10269,
#   'total_number_of_ratings_i': 112,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Frank G.',
#   'teacherlastname_t': 'Reynolds'},
#  {'averageratingscore_rf': 4.5,
#   'pk_id': 1360012,
#   'total_number_of_ratings_i': 112,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Surya',
#   'teacherlastname_t': 'Banerjee'},
#  {'averageratingscore_rf': 4.45,
#   'pk_id': 72789,
#   'total_number_of_ratings_i': 111,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'David',
#   'teacherlastname_t': 'Harmsworth'},
#  {'averageratingscore_rf': 2.9,
#   'pk_id': 906766,
#   'total_number_of_ratings_i': 111,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Heidi',
#   'teacherlastname_t': 'Engelhardt'},
#  {'averageratingscore_rf': 2.57,
#   'pk_id': 11538,
#   'total_number_of_ratings_i': 110,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Grant',
#   'teacherlastname_t': 'Russell'},
#  {'averageratingscore_rf': 3.89,
#   'pk_id': 22795,
#   'total_number_of_ratings_i': 107,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Kenneth',
#   'teacherlastname_t': 'Westhues'},
#  {'averageratingscore_rf': 2.7,
#   'pk_id': 35524,
#   'total_number_of_ratings_i': 107,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Augie',
#   'teacherlastname_t': 'Fleras'},
#  {'averageratingscore_rf': 4.4,
#   'pk_id': 461947,
#   'total_number_of_ratings_i': 107,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Joseph J.',
#   'teacherlastname_t': 'West'},
#  {'averageratingscore_rf': 3.7,
#   'pk_id': 420555,
#   'total_number_of_ratings_i': 106,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Vivian',
#   'teacherlastname_t': 'Dayeh'},
#  {'averageratingscore_rf': 4.15,
#   'pk_id': 9330,
#   'total_number_of_ratings_i': 101,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Richard A',
#   'teacherlastname_t': 'Nutbrown'},
#  {'averageratingscore_rf': 2.9,
#   'pk_id': 10116,
#   'total_number_of_ratings_i': 101,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Trevor',
#   'teacherlastname_t': 'Charles'},
#  {'averageratingscore_rf': 4.7,
#   'pk_id': 67502,
#   'total_number_of_ratings_i': 101,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Simon',
#   'teacherlastname_t': 'Wood'},
#  {'averageratingscore_rf': 4.0,
#   'pk_id': 73057,
#   'total_number_of_ratings_i': 100,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Doug',
#   'teacherlastname_t': 'Park'},
#  {'averageratingscore_rf': 4.8,
#   'pk_id': 14385,
#   'total_number_of_ratings_i': 99,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Andrew',
#   'teacherlastname_t': 'Hunt'},
#  {'averageratingscore_rf': 4.9,
#   'pk_id': 1136546,
#   'total_number_of_ratings_i': 99,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Josh',
#   'teacherlastname_t': 'Neufeld'},
#  {'averageratingscore_rf': 1.97,
#   'pk_id': 10089,
#   'total_number_of_ratings_i': 98,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Trien',
#   'teacherlastname_t': 'Nguyen'},
#  {'averageratingscore_rf': 3.47,
#   'pk_id': 10325,
#   'total_number_of_ratings_i': 97,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Bill',
#   'teacherlastname_t': 'Moul'},
#  {'averageratingscore_rf': 4.51,
#   'pk_id': 10531,
#   'total_number_of_ratings_i': 97,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Frank',
#   'teacherlastname_t': 'Zorzitto'},
#  {'averageratingscore_rf': 3.1,
#   'pk_id': 14352,
#   'total_number_of_ratings_i': 97,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Changbao',
#   'teacherlastname_t': 'Wu'},
#  {'averageratingscore_rf': 4.8,
#   'pk_id': 552465,
#   'total_number_of_ratings_i': 97,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Mike',
#   'teacherlastname_t': 'Eden'},
#  {'averageratingscore_rf': 4.3,
#   'pk_id': 10905,
#   'total_number_of_ratings_i': 96,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Gerard',
#   'teacherlastname_t': 'Boychuk'},
#  {'averageratingscore_rf': 3.4,
#   'pk_id': 14286,
#   'total_number_of_ratings_i': 95,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'David',
#   'teacherlastname_t': 'Seljak'},
#  {'averageratingscore_rf': 2.2,
#   'pk_id': 822381,
#   'total_number_of_ratings_i': 95,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Dara',
#   'teacherlastname_t': 'Gilbert'},
#  {'averageratingscore_rf': 3.97,
#   'pk_id': 12465,
#   'total_number_of_ratings_i': 94,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Jeffrey',
#   'teacherlastname_t': 'Shallit'},
#  {'averageratingscore_rf': 4.1,
#   'pk_id': 15741,
#   'total_number_of_ratings_i': 94,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Peter',
#   'teacherlastname_t': 'Wood'},
#  {'averageratingscore_rf': 4.5,
#   'pk_id': 10537,
#   'total_number_of_ratings_i': 94,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Steve',
#   'teacherlastname_t': 'Furino'},
#  {'averageratingscore_rf': 2.9,
#   'pk_id': 1272225,
#   'total_number_of_ratings_i': 93,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Nafeez',
#   'teacherlastname_t': 'Fatima'},
#  {'averageratingscore_rf': 4.29,
#   'pk_id': 13795,
#   'total_number_of_ratings_i': 92,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Duane',
#   'teacherlastname_t': 'Kennedy'},
#  {'averageratingscore_rf': 4.7,
#   'pk_id': 214927,
#   'total_number_of_ratings_i': 92,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Brent',
#   'teacherlastname_t': 'Doberstein'},
#  {'averageratingscore_rf': 4.5,
#   'pk_id': 19144,
#   'total_number_of_ratings_i': 91,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Giuseppe',
#   'teacherlastname_t': 'Tenti'},
#  {'averageratingscore_rf': 4.43,
#   'pk_id': 20176,
#   'total_number_of_ratings_i': 91,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Jean',
#   'teacherlastname_t': 'Andrey'},
#  {'averageratingscore_rf': 3.94,
#   'pk_id': 10487,
#   'total_number_of_ratings_i': 90,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Bev',
#   'teacherlastname_t': 'Marshman'},
#  {'averageratingscore_rf': 2.8,
#   'pk_id': 13891,
#   'total_number_of_ratings_i': 90,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Peter',
#   'teacherlastname_t': 'Woolstencroft'},
#  {'averageratingscore_rf': 3.8,
#   'pk_id': 14308,
#   'total_number_of_ratings_i': 90,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Lori Michelle',
#   'teacherlastname_t': 'Case'},
#  {'averageratingscore_rf': 3.97,
#   'pk_id': 10048,
#   'total_number_of_ratings_i': 90,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Robert',
#   'teacherlastname_t': 'McKillop'},
#  {'averageratingscore_rf': 3.7,
#   'pk_id': 40380,
#   'total_number_of_ratings_i': 89,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Ramadan',
#   'teacherlastname_t': 'El-Shatshat'},
#  {'averageratingscore_rf': 2.6,
#   'pk_id': 39828,
#   'total_number_of_ratings_i': 89,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'David',
#   'teacherlastname_t': 'Schweitzer'},
#  {'averageratingscore_rf': 4.6,
#   'pk_id': 10033,
#   'total_number_of_ratings_i': 88,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Peter',
#   'teacherlastname_t': 'Buhr'},
#  {'averageratingscore_rf': 4.8,
#   'pk_id': 12575,
#   'total_number_of_ratings_i': 88,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Abdul Rahim',
#   'teacherlastname_t': 'Ahmad'},
#  {'averageratingscore_rf': 4.7,
#   'pk_id': 256596,
#   'total_number_of_ratings_i': 88,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Yu-Ru',
#   'teacherlastname_t': 'Liu'},
#  {'averageratingscore_rf': 1.87,
#   'pk_id': 1183401,
#   'total_number_of_ratings_i': 88,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Brent James',
#   'teacherlastname_t': 'Matheson'},
#  {'averageratingscore_rf': 3.37,
#   'pk_id': 10030,
#   'total_number_of_ratings_i': 87,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Che Tat',
#   'teacherlastname_t': 'Ng'},
#  {'averageratingscore_rf': 2.8,
#   'pk_id': 10486,
#   'total_number_of_ratings_i': 86,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Therese',
#   'teacherlastname_t': 'Sabaryn'},
#  {'averageratingscore_rf': 4.9,
#   'pk_id': 1337681,
#   'total_number_of_ratings_i': 86,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Eddie',
#   'teacherlastname_t': 'Dupont'},
#  {'averageratingscore_rf': 2.9,
#   'pk_id': 69249,
#   'total_number_of_ratings_i': 86,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Stephanie',
#   'teacherlastname_t': 'Gregoire'},
#  {'averageratingscore_rf': 4.16,
#   'pk_id': 32015,
#   'total_number_of_ratings_i': 85,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Steve',
#   'teacherlastname_t': 'Drekic'},
#  {'averageratingscore_rf': 3.75,
#   'pk_id': 21147,
#   'total_number_of_ratings_i': 84,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Maureen',
#   'teacherlastname_t': 'Drysdale'},
#  {'averageratingscore_rf': 3.5,
#   'pk_id': 39312,
#   'total_number_of_ratings_i': 84,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Barbara',
#   'teacherlastname_t': 'Moffatt'},
#  {'averageratingscore_rf': 4.7,
#   'pk_id': 13693,
#   'total_number_of_ratings_i': 83,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Pierre',
#   'teacherlastname_t': 'Filion'},
#  {'averageratingscore_rf': 3.8,
#   'pk_id': 10180,
#   'total_number_of_ratings_i': 82,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Zoran',
#   'teacherlastname_t': 'Miskovic'},
#  {'averageratingscore_rf': 3.19,
#   'pk_id': 17159,
#   'total_number_of_ratings_i': 82,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Javier',
#   'teacherlastname_t': 'Cuenca'},
#  {'averageratingscore_rf': 3.7,
#   'pk_id': 35083,
#   'total_number_of_ratings_i': 82,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Glenn',
#   'teacherlastname_t': 'Ward'},
#  {'averageratingscore_rf': 4.3,
#   'pk_id': 12844,
#   'total_number_of_ratings_i': 82,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Ross',
#   'teacherlastname_t': 'Willard'},
#  {'averageratingscore_rf': 4.0,
#   'pk_id': 374845,
#   'total_number_of_ratings_i': 81,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Brad',
#   'teacherlastname_t': 'Lushman'},
#  {'averageratingscore_rf': 4.0,
#   'pk_id': 856197,
#   'total_number_of_ratings_i': 80,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Corey',
#   'teacherlastname_t': 'Van De Waal'},
#  {'averageratingscore_rf': 2.4,
#   'pk_id': 10388,
#   'total_number_of_ratings_i': 78,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Brian',
#   'teacherlastname_t': 'Cozzarin'},
#  {'averageratingscore_rf': 2.0,
#   'pk_id': 18359,
#   'total_number_of_ratings_i': 78,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Henry',
#   'teacherlastname_t': 'Wolkowicz'},
#  {'averageratingscore_rf': 4.3,
#   'pk_id': 1621313,
#   'total_number_of_ratings_i': 78,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Parisa',
#   'teacherlastname_t': 'Bohlouli'},
#  {'averageratingscore_rf': 3.73,
#   'pk_id': 10880,
#   'total_number_of_ratings_i': 78,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Barry',
#   'teacherlastname_t': 'Ferguson'},
#  {'averageratingscore_rf': 1.9,
#   'pk_id': 12448,
#   'total_number_of_ratings_i': 78,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Caroline',
#   'teacherlastname_t': 'Kierstead'},
#  {'averageratingscore_rf': 3.5,
#   'pk_id': 23632,
#   'total_number_of_ratings_i': 78,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Ladan',
#   'teacherlastname_t': 'Tahvildari'},
#  {'averageratingscore_rf': 3.0,
#   'pk_id': 32314,
#   'total_number_of_ratings_i': 77,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Joan',
#   'teacherlastname_t': 'Coutu'},
#  {'averageratingscore_rf': 4.0,
#   'pk_id': 1653925,
#   'total_number_of_ratings_i': 77,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Mukto',
#   'teacherlastname_t': 'Akash'},
#  {'averageratingscore_rf': 4.2,
#   'pk_id': 829723,
#   'total_number_of_ratings_i': 77,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Mark',
#   'teacherlastname_t': 'Petrick'},
#  {'averageratingscore_rf': 1.66,
#   'pk_id': 10032,
#   'total_number_of_ratings_i': 76,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Paul',
#   'teacherlastname_t': 'Kates'},
#  {'averageratingscore_rf': 2.8,
#   'pk_id': 425329,
#   'total_number_of_ratings_i': 76,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Jun',
#   'teacherlastname_t': 'Cai'},
#  {'averageratingscore_rf': 4.5,
#   'pk_id': 1508857,
#   'total_number_of_ratings_i': 76,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Igor',
#   'teacherlastname_t': 'Ivkovic'},
#  {'averageratingscore_rf': 3.8,
#   'pk_id': 253528,
#   'total_number_of_ratings_i': 76,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Wentang',
#   'teacherlastname_t': 'Kuo'},
#  {'averageratingscore_rf': 4.3,
#   'pk_id': 1626426,
#   'total_number_of_ratings_i': 76,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Dave',
#   'teacherlastname_t': 'Tompkins'},
#  {'averageratingscore_rf': 2.41,
#   'pk_id': 10015,
#   'total_number_of_ratings_i': 75,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Carolyn',
#   'teacherlastname_t': 'MacGregor'},
#  {'averageratingscore_rf': 2.9,
#   'pk_id': 21218,
#   'total_number_of_ratings_i': 75,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Peter',
#   'teacherlastname_t': 'Balka'},
#  {'averageratingscore_rf': 3.3,
#   'pk_id': 40768,
#   'total_number_of_ratings_i': 75,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Mu',
#   'teacherlastname_t': 'Zhu'},
#  {'averageratingscore_rf': 3.5,
#   'pk_id': 56097,
#   'total_number_of_ratings_i': 74,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Anindya',
#   'teacherlastname_t': 'Sen'},
#  {'averageratingscore_rf': 3.59,
#   'pk_id': 426032,
#   'total_number_of_ratings_i': 74,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Emmanuelle',
#   'teacherlastname_t': 'Pierard'},
#  {'averageratingscore_rf': 3.5,
#   'pk_id': 161613,
#   'total_number_of_ratings_i': 73,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Mohamed-Yahia',
#   'teacherlastname_t': 'Dabbagh'},
#  {'averageratingscore_rf': 3.08,
#   'pk_id': 9798,
#   'total_number_of_ratings_i': 73,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Cathy',
#   'teacherlastname_t': 'Gebotys'},
#  {'averageratingscore_rf': 3.16,
#   'pk_id': 11695,
#   'total_number_of_ratings_i': 73,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Jennifer',
#   'teacherlastname_t': 'Stolz'},
#  {'averageratingscore_rf': 3.12,
#   'pk_id': 10151,
#   'total_number_of_ratings_i': 72,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Stanley',
#   'teacherlastname_t': 'Lipshitz'},
#  {'averageratingscore_rf': 2.19,
#   'pk_id': 10154,
#   'total_number_of_ratings_i': 72,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'William Bill',
#   'teacherlastname_t': 'Cowan'},
#  {'averageratingscore_rf': 3.78,
#   'pk_id': 10322,
#   'total_number_of_ratings_i': 72,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Stan',
#   'teacherlastname_t': 'Fogel'},
#  {'averageratingscore_rf': 1.6,
#   'pk_id': 23397,
#   'total_number_of_ratings_i': 72,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Edward',
#   'teacherlastname_t': 'Chan'},
#  {'averageratingscore_rf': 4.8,
#   'pk_id': 251641,
#   'total_number_of_ratings_i': 72,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Gary',
#   'teacherlastname_t': 'Bruce'},
#  {'averageratingscore_rf': 2.92,
#   'pk_id': 9796,
#   'total_number_of_ratings_i': 72,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'C. R.',
#   'teacherlastname_t': 'Selvakumar'},
#  {'averageratingscore_rf': 1.6,
#   'pk_id': 56084,
#   'total_number_of_ratings_i': 72,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'David',
#   'teacherlastname_t': 'Toman'},
#  {'averageratingscore_rf': 4.67,
#   'pk_id': 10589,
#   'total_number_of_ratings_i': 70,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Brian',
#   'teacherlastname_t': 'Forrest'},
#  {'averageratingscore_rf': 3.44,
#   'pk_id': 14020,
#   'total_number_of_ratings_i': 70,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Alan',
#   'teacherlastname_t': 'Morgan'},
#  {'averageratingscore_rf': 2.99,
#   'pk_id': 9859,
#   'total_number_of_ratings_i': 70,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Gunter',
#   'teacherlastname_t': 'Scholz'},
#  {'averageratingscore_rf': 3.4,
#   'pk_id': 16471,
#   'total_number_of_ratings_i': 69,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'John',
#   'teacherlastname_t': 'Rempel'},
#  {'averageratingscore_rf': 4.3,
#   'pk_id': 1786945,
#   'total_number_of_ratings_i': 69,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Eduardo',
#   'teacherlastname_t': 'Martin-Martinez'},
#  {'averageratingscore_rf': 2.75,
#   'pk_id': 31608,
#   'total_number_of_ratings_i': 69,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Tracy',
#   'teacherlastname_t': 'Peressini'},
#  {'averageratingscore_rf': 3.2,
#   'pk_id': 9815,
#   'total_number_of_ratings_i': 68,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'June',
#   'teacherlastname_t': 'Lowe'},
#  {'averageratingscore_rf': 4.8,
#   'pk_id': 10548,
#   'total_number_of_ratings_i': 68,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Riemer',
#   'teacherlastname_t': 'Faber'},
#  {'averageratingscore_rf': 2.84,
#   'pk_id': 9804,
#   'total_number_of_ratings_i': 67,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Rudolph',
#   'teacherlastname_t': 'Seviora'},
#  {'averageratingscore_rf': 4.38,
#   'pk_id': 10488,
#   'total_number_of_ratings_i': 67,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Chris',
#   'teacherlastname_t': 'Springer'},
#  {'averageratingscore_rf': 3.51,
#   'pk_id': 67536,
#   'total_number_of_ratings_i': 67,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Scott',
#   'teacherlastname_t': 'Kline'},
#  {'averageratingscore_rf': 4.1,
#   'pk_id': 193792,
#   'total_number_of_ratings_i': 67,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'William',
#   'teacherlastname_t': 'Bishop'},
#  {'averageratingscore_rf': 4.6,
#   'pk_id': 648833,
#   'total_number_of_ratings_i': 67,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Richard',
#   'teacherlastname_t': 'Epp'},
#  {'averageratingscore_rf': 2.7,
#   'pk_id': 9818,
#   'total_number_of_ratings_i': 66,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Wayne M',
#   'teacherlastname_t': 'Loucks'},
#  {'averageratingscore_rf': 2.75,
#   'pk_id': 10711,
#   'total_number_of_ratings_i': 66,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Robert',
#   'teacherlastname_t': 'Le Roy'},
#  {'averageratingscore_rf': 3.8,
#   'pk_id': 24366,
#   'total_number_of_ratings_i': 66,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Geoff',
#   'teacherlastname_t': 'Hayes'},
#  {'averageratingscore_rf': 4.3,
#   'pk_id': 731540,
#   'total_number_of_ratings_i': 66,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Fiona',
#   'teacherlastname_t': 'Dunbar'},
#  {'averageratingscore_rf': 4.8,
#   'pk_id': 119115,
#   'total_number_of_ratings_i': 66,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Daniel',
#   'teacherlastname_t': 'Hutter'},
#  {'averageratingscore_rf': 4.2,
#   'pk_id': 1216503,
#   'total_number_of_ratings_i': 66,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Martin',
#   'teacherlastname_t': 'Pei'},
#  {'averageratingscore_rf': 4.3,
#   'pk_id': 1488924,
#   'total_number_of_ratings_i': 66,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Reza',
#   'teacherlastname_t': 'Ramezan'},
#  {'averageratingscore_rf': 4.14,
#   'pk_id': 10323,
#   'total_number_of_ratings_i': 65,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Paul',
#   'teacherlastname_t': 'Kreller'},
#  {'averageratingscore_rf': 4.92,
#   'pk_id': 1754724,
#   'total_number_of_ratings_i': 65,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Houman',
#   'teacherlastname_t': 'Mortazavi'},
#  {'averageratingscore_rf': 1.87,
#   'pk_id': 10485,
#   'total_number_of_ratings_i': 64,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Farhad',
#   'teacherlastname_t': 'Mavaddat'},
#  {'averageratingscore_rf': 4.8,
#   'pk_id': 15025,
#   'total_number_of_ratings_i': 64,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Alfred John',
#   'teacherlastname_t': 'Menezes'},
#  {'averageratingscore_rf': 4.31,
#   'pk_id': 11711,
#   'total_number_of_ratings_i': 63,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Maria',
#   'teacherlastname_t': 'Liston'},
#  {'averageratingscore_rf': 4.8,
#   'pk_id': 227279,
#   'total_number_of_ratings_i': 63,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Craig',
#   'teacherlastname_t': 'Kaplan'},
#  {'averageratingscore_rf': 3.64,
#   'pk_id': 13880,
#   'total_number_of_ratings_i': 62,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Chris',
#   'teacherlastname_t': 'Eliasmith'},
#  {'averageratingscore_rf': 3.1,
#   'pk_id': 14094,
#   'total_number_of_ratings_i': 62,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Jan',
#   'teacherlastname_t': 'Narveson'},
#  {'averageratingscore_rf': 3.5,
#   'pk_id': 15026,
#   'total_number_of_ratings_i': 62,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Frank',
#   'teacherlastname_t': 'Safayeni'},
#  {'averageratingscore_rf': 3.93,
#   'pk_id': 15190,
#   'total_number_of_ratings_i': 62,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Paul',
#   'teacherlastname_t': 'Schellenberg'},
#  {'averageratingscore_rf': 2.9,
#   'pk_id': 38110,
#   'total_number_of_ratings_i': 62,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Nancy',
#   'teacherlastname_t': 'Day'},
#  {'averageratingscore_rf': 3.35,
#   'pk_id': 777282,
#   'total_number_of_ratings_i': 62,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Dong',
#   'teacherlastname_t': 'Chang'},
#  {'averageratingscore_rf': 4.6,
#   'pk_id': 1736070,
#   'total_number_of_ratings_i': 62,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Victoria',
#   'teacherlastname_t': 'Sakhnini'},
#  {'averageratingscore_rf': 4.8,
#   'pk_id': 11107,
#   'total_number_of_ratings_i': 62,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Wei Chau',
#   'teacherlastname_t': 'Xie'},
#  {'averageratingscore_rf': 3.7,
#   'pk_id': 65555,
#   'total_number_of_ratings_i': 62,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Joseph',
#   'teacherlastname_t': 'Sanderson'},
#  {'averageratingscore_rf': 3.6,
#   'pk_id': 1862249,
#   'total_number_of_ratings_i': 61,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Zara',
#   'teacherlastname_t': 'Liaqat'},
#  {'averageratingscore_rf': 4.2,
#   'pk_id': 17145,
#   'total_number_of_ratings_i': 61,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Tim',
#   'teacherlastname_t': 'Brecht'},
#  {'averageratingscore_rf': 2.13,
#   'pk_id': 9834,
#   'total_number_of_ratings_i': 60,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Kevin',
#   'teacherlastname_t': 'Lamb'},
#  {'averageratingscore_rf': 3.2,
#   'pk_id': 10177,
#   'total_number_of_ratings_i': 60,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Bruce',
#   'teacherlastname_t': 'Richter'},
#  {'averageratingscore_rf': 3.37,
#   'pk_id': 15161,
#   'total_number_of_ratings_i': 60,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'John',
#   'teacherlastname_t': 'Lawrence'},
#  {'averageratingscore_rf': 4.0,
#   'pk_id': 28422,
#   'total_number_of_ratings_i': 60,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Monica',
#   'teacherlastname_t': 'Barra'},
#  {'averageratingscore_rf': 2.7,
#   'pk_id': 1193352,
#   'total_number_of_ratings_i': 60,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Pirapagaran',
#   'teacherlastname_t': 'Tharmalingam'},
#  {'averageratingscore_rf': 3.1,
#   'pk_id': 248543,
#   'total_number_of_ratings_i': 60,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Michael',
#   'teacherlastname_t': 'Rubinstein'},
#  {'averageratingscore_rf': 4.2,
#   'pk_id': 10912,
#   'total_number_of_ratings_i': 60,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Alexandru',
#   'teacherlastname_t': 'Nica'},
#  {'averageratingscore_rf': 3.85,
#   'pk_id': 10909,
#   'total_number_of_ratings_i': 59,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Timothy',
#   'teacherlastname_t': 'Chan'},
#  {'averageratingscore_rf': 3.15,
#   'pk_id': 27387,
#   'total_number_of_ratings_i': 59,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Brian',
#   'teacherlastname_t': 'Dixon'},
#  {'averageratingscore_rf': 4.2,
#   'pk_id': 733223,
#   'total_number_of_ratings_i': 59,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Jonathan',
#   'teacherlastname_t': 'Fugelsang'},
#  {'averageratingscore_rf': 4.8,
#   'pk_id': 12272,
#   'total_number_of_ratings_i': 59,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Ron',
#   'teacherlastname_t': 'McCarville'},
#  {'averageratingscore_rf': 3.9,
#   'pk_id': 24298,
#   'total_number_of_ratings_i': 59,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Steve',
#   'teacherlastname_t': 'Murphy'},
#  {'averageratingscore_rf': 2.7,
#   'pk_id': 81310,
#   'total_number_of_ratings_i': 59,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Leonardo',
#   'teacherlastname_t': 'Simon'},
#  {'averageratingscore_rf': 3.68,
#   'pk_id': 10906,
#   'total_number_of_ratings_i': 58,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Suzanne',
#   'teacherlastname_t': 'Safayeni'},
#  {'averageratingscore_rf': 4.7,
#   'pk_id': 425192,
#   'total_number_of_ratings_i': 58,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'J. Andrew',
#   'teacherlastname_t': 'Deman'},
#  {'averageratingscore_rf': 4.36,
#   'pk_id': 1482251,
#   'total_number_of_ratings_i': 58,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Clinton',
#   'teacherlastname_t': 'Loo'},
#  {'averageratingscore_rf': 3.3,
#   'pk_id': 10133,
#   'total_number_of_ratings_i': 58,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Mario',
#   'teacherlastname_t': 'Ioannidis'},
#  {'averageratingscore_rf': 3.9,
#   'pk_id': 39219,
#   'total_number_of_ratings_i': 58,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Ed',
#   'teacherlastname_t': 'Janzen'},
#  {'averageratingscore_rf': 3.5,
#   'pk_id': 1178638,
#   'total_number_of_ratings_i': 58,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Fiona T',
#   'teacherlastname_t': 'Rahman'},
#  {'averageratingscore_rf': 3.5,
#   'pk_id': 30643,
#   'total_number_of_ratings_i': 57,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Barbara',
#   'teacherlastname_t': 'Butler'},
#  {'averageratingscore_rf': 3.9,
#   'pk_id': 37657,
#   'total_number_of_ratings_i': 57,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Michael',
#   'teacherlastname_t': 'MacDonald'},
#  {'averageratingscore_rf': 2.1,
#   'pk_id': 22613,
#   'total_number_of_ratings_i': 57,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Scott',
#   'teacherlastname_t': 'Taylor'},
#  {'averageratingscore_rf': 3.3,
#   'pk_id': 14955,
#   'total_number_of_ratings_i': 57,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'David G.',
#   'teacherlastname_t': 'Wagner'},
#  {'averageratingscore_rf': 1.8,
#   'pk_id': 10092,
#   'total_number_of_ratings_i': 57,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Gordon',
#   'teacherlastname_t': 'Savage'},
#  {'averageratingscore_rf': 1.5,
#   'pk_id': 13895,
#   'total_number_of_ratings_i': 56,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Bosco H',
#   'teacherlastname_t': 'Leung'},
#  {'averageratingscore_rf': 2.3,
#   'pk_id': 24135,
#   'total_number_of_ratings_i': 56,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Mike',
#   'teacherlastname_t': 'Fich'},
#  {'averageratingscore_rf': 4.7,
#   'pk_id': 29844,
#   'total_number_of_ratings_i': 56,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Yasser',
#   'teacherlastname_t': 'Hegazy'},
#  {'averageratingscore_rf': 3.42,
#   'pk_id': 177974,
#   'total_number_of_ratings_i': 56,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Elisabeth',
#   'teacherlastname_t': 'Daub'},
#  {'averageratingscore_rf': 4.4,
#   'pk_id': 832326,
#   'total_number_of_ratings_i': 56,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Ali',
#   'teacherlastname_t': 'Elkamel'},
#  {'averageratingscore_rf': 4.3,
#   'pk_id': 870995,
#   'total_number_of_ratings_i': 56,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Ronald',
#   'teacherlastname_t': 'Kroeker'},
#  {'averageratingscore_rf': 2.7,
#   'pk_id': 1161476,
#   'total_number_of_ratings_i': 56,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Patrick',
#   'teacherlastname_t': 'Roh'},
#  {'averageratingscore_rf': 4.9,
#   'pk_id': 2219823,
#   'total_number_of_ratings_i': 56,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Mohammed',
#   'teacherlastname_t': 'Nassar'},
#  {'averageratingscore_rf': 4.75,
#   'pk_id': 10399,
#   'total_number_of_ratings_i': 55,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Stanley',
#   'teacherlastname_t': 'Laiken'},
#  {'averageratingscore_rf': 1.63,
#   'pk_id': 892966,
#   'total_number_of_ratings_i': 55,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Derek',
#   'teacherlastname_t': 'Pyne'},
#  {'averageratingscore_rf': 2.56,
#   'pk_id': 10002,
#   'total_number_of_ratings_i': 54,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Chris',
#   'teacherlastname_t': 'Godsil'},
#  {'averageratingscore_rf': 3.93,
#   'pk_id': 10945,
#   'total_number_of_ratings_i': 54,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Arnie',
#   'teacherlastname_t': 'Dyck'},
#  {'averageratingscore_rf': 2.9,
#   'pk_id': 11513,
#   'total_number_of_ratings_i': 54,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Derek',
#   'teacherlastname_t': 'Besner'},
#  {'averageratingscore_rf': 3.77,
#   'pk_id': 13741,
#   'total_number_of_ratings_i': 54,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Tim',
#   'teacherlastname_t': 'Kenyon'},
#  {'averageratingscore_rf': 4.8,
#   'pk_id': 14124,
#   'total_number_of_ratings_i': 54,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Laura',
#   'teacherlastname_t': 'Gray'},
#  {'averageratingscore_rf': 2.3,
#   'pk_id': 16687,
#   'total_number_of_ratings_i': 54,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Andrei',
#   'teacherlastname_t': 'Sazonov'},
#  {'averageratingscore_rf': 3.8,
#   'pk_id': 20093,
#   'total_number_of_ratings_i': 54,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Achim',
#   'teacherlastname_t': 'Kempf'},
#  {'averageratingscore_rf': 4.61,
#   'pk_id': 1044582,
#   'total_number_of_ratings_i': 54,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Frances',
#   'teacherlastname_t': 'Chapman'},
#  {'averageratingscore_rf': 3.94,
#   'pk_id': 1403130,
#   'total_number_of_ratings_i': 54,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Andrew',
#   'teacherlastname_t': 'Beltaos'},
#  {'averageratingscore_rf': 4.49,
#   'pk_id': 1480565,
#   'total_number_of_ratings_i': 54,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Fran',
#   'teacherlastname_t': 'Allard'},
#  {'averageratingscore_rf': 3.5,
#   'pk_id': 69977,
#   'total_number_of_ratings_i': 54,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'John',
#   'teacherlastname_t': 'Burbidge'},
#  {'averageratingscore_rf': 2.3,
#   'pk_id': 901157,
#   'total_number_of_ratings_i': 54,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Sonny',
#   'teacherlastname_t': 'Lee'},
#  {'averageratingscore_rf': 4.03,
#   'pk_id': 13860,
#   'total_number_of_ratings_i': 53,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Stefan',
#   'teacherlastname_t': 'Idziak'},
#  {'averageratingscore_rf': 4.89,
#   'pk_id': 459923,
#   'total_number_of_ratings_i': 53,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Savvas',
#   'teacherlastname_t': 'Damaskinos'},
#  {'averageratingscore_rf': 2.83,
#   'pk_id': 477714,
#   'total_number_of_ratings_i': 53,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'N',
#   'teacherlastname_t': 'Zunic'},
#  {'averageratingscore_rf': 3.7,
#   'pk_id': 16934,
#   'total_number_of_ratings_i': 53,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Gerd',
#   'teacherlastname_t': 'Hauck'},
#  {'averageratingscore_rf': 1.8,
#   'pk_id': 186936,
#   'total_number_of_ratings_i': 53,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Paul',
#   'teacherlastname_t': 'Ward'},
#  {'averageratingscore_rf': 2.72,
#   'pk_id': 11074,
#   'total_number_of_ratings_i': 52,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Robert',
#   'teacherlastname_t': 'Prus'},
#  {'averageratingscore_rf': 3.63,
#   'pk_id': 14480,
#   'total_number_of_ratings_i': 52,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Kenneth',
#   'teacherlastname_t': 'Salem'},
#  {'averageratingscore_rf': 3.37,
#   'pk_id': 32000,
#   'total_number_of_ratings_i': 52,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Ken Seng',
#   'teacherlastname_t': 'Tan'},
#  {'averageratingscore_rf': 4.53,
#   'pk_id': 38572,
#   'total_number_of_ratings_i': 52,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Jon',
#   'teacherlastname_t': 'Boyd'},
#  {'averageratingscore_rf': 3.1,
#   'pk_id': 1330675,
#   'total_number_of_ratings_i': 52,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Diana K.',
#   'teacherlastname_t': 'Skrzydlo'},
#  {'averageratingscore_rf': 2.9,
#   'pk_id': 65944,
#   'total_number_of_ratings_i': 52,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Darren',
#   'teacherlastname_t': 'Charters'},
#  {'averageratingscore_rf': 3.5,
#   'pk_id': 824510,
#   'total_number_of_ratings_i': 52,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Robert',
#   'teacherlastname_t': 'Ducharme'},
#  {'averageratingscore_rf': 4.5,
#   'pk_id': 9793,
#   'total_number_of_ratings_i': 51,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Lynn',
#   'teacherlastname_t': 'Taylor'},
#  {'averageratingscore_rf': 4.46,
#   'pk_id': 10166,
#   'total_number_of_ratings_i': 51,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Naomi',
#   'teacherlastname_t': 'Nishimura'},
#  {'averageratingscore_rf': 4.1,
#   'pk_id': 13796,
#   'total_number_of_ratings_i': 51,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'John',
#   'teacherlastname_t': 'Wainwright'},
#  {'averageratingscore_rf': 2.3,
#   'pk_id': 14307,
#   'total_number_of_ratings_i': 51,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'John G',
#   'teacherlastname_t': 'Thistle'},
#  {'averageratingscore_rf': 4.0,
#   'pk_id': 18064,
#   'total_number_of_ratings_i': 51,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Regina',
#   'teacherlastname_t': 'Vera-Quinn'},
#  {'averageratingscore_rf': 3.99,
#   'pk_id': 23022,
#   'total_number_of_ratings_i': 51,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Kathy',
#   'teacherlastname_t': 'Acheson'},
#  {'averageratingscore_rf': 2.07,
#   'pk_id': 41174,
#   'total_number_of_ratings_i': 51,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Robert',
#   'teacherlastname_t': 'Shipley'},
#  {'averageratingscore_rf': 3.3,
#   'pk_id': 236279,
#   'total_number_of_ratings_i': 51,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Otman',
#   'teacherlastname_t': 'Basir'},
#  {'averageratingscore_rf': 3.7,
#   'pk_id': 10229,
#   'total_number_of_ratings_i': 51,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Mary',
#   'teacherlastname_t': 'Hardy'},
#  {'averageratingscore_rf': 4.5,
#   'pk_id': 441599,
#   'total_number_of_ratings_i': 51,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Toni',
#   'teacherlastname_t': 'Serafini'},
#  {'averageratingscore_rf': 4.6,
#   'pk_id': 1177241,
#   'total_number_of_ratings_i': 51,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Kashif',
#   'teacherlastname_t': 'Memon'},
#  {'averageratingscore_rf': 3.4,
#   'pk_id': 10111,
#   'total_number_of_ratings_i': 51,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Eugene',
#   'teacherlastname_t': 'Zima'},
#  {'averageratingscore_rf': 4.31,
#   'pk_id': 13594,
#   'total_number_of_ratings_i': 50,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Jock',
#   'teacherlastname_t': 'MacKay'},
#  {'averageratingscore_rf': 3.39,
#   'pk_id': 39363,
#   'total_number_of_ratings_i': 50,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Linda',
#   'teacherlastname_t': 'Warley'},
#  {'averageratingscore_rf': 3.2,
#   'pk_id': 38573,
#   'total_number_of_ratings_i': 50,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Hsiao',
#   'teacherlastname_t': "D'Ailly"},
#  {'averageratingscore_rf': 3.3,
#   'pk_id': 511030,
#   'total_number_of_ratings_i': 50,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Bessma',
#   'teacherlastname_t': 'Momani'},
#  {'averageratingscore_rf': 2.5,
#   'pk_id': 25790,
#   'total_number_of_ratings_i': 50,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Arne',
#   'teacherlastname_t': 'Storjohann'},
#  {'averageratingscore_rf': 4.3,
#   'pk_id': 18269,
#   'total_number_of_ratings_i': 50,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Edward',
#   'teacherlastname_t': 'Vrscay'},
#  {'averageratingscore_rf': 4.5,
#   'pk_id': 463279,
#   'total_number_of_ratings_i': 50,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Jean-Paul',
#   'teacherlastname_t': 'Lam'},
#  {'averageratingscore_rf': 2.01,
#   'pk_id': 10099,
#   'total_number_of_ratings_i': 49,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Richard',
#   'teacherlastname_t': 'Mann'},
#  {'averageratingscore_rf': 3.33,
#   'pk_id': 10191,
#   'total_number_of_ratings_i': 49,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Xianshe',
#   'teacherlastname_t': 'Feng'},
#  {'averageratingscore_rf': 2.64,
#   'pk_id': 10205,
#   'total_number_of_ratings_i': 49,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Chrysanne',
#   'teacherlastname_t': 'Dimarco'},
#  {'averageratingscore_rf': 3.23,
#   'pk_id': 41316,
#   'total_number_of_ratings_i': 49,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Nadine',
#   'teacherlastname_t': 'Gingrich'},
#  {'averageratingscore_rf': 2.38,
#   'pk_id': 726823,
#   'total_number_of_ratings_i': 49,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Christian',
#   'teacherlastname_t': 'Jacobson'},
#  {'averageratingscore_rf': 3.4,
#   'pk_id': 10215,
#   'total_number_of_ratings_i': 49,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Jacob',
#   'teacherlastname_t': 'Fisher'},
#  {'averageratingscore_rf': 4.2,
#   'pk_id': 1396461,
#   'total_number_of_ratings_i': 49,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Richard',
#   'teacherlastname_t': 'Eibach'},
#  {'averageratingscore_rf': 2.8,
#   'pk_id': 24617,
#   'total_number_of_ratings_i': 48,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Mark',
#   'teacherlastname_t': 'Morley'},
#  {'averageratingscore_rf': 4.45,
#   'pk_id': 29496,
#   'total_number_of_ratings_i': 48,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Sheila',
#   'teacherlastname_t': 'Ager'},
#  {'averageratingscore_rf': 2.6,
#   'pk_id': 42246,
#   'total_number_of_ratings_i': 48,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Beverley',
#   'teacherlastname_t': 'Bell-Rowbotham'},
#  {'averageratingscore_rf': 3.01,
#   'pk_id': 96886,
#   'total_number_of_ratings_i': 48,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Mengsteab',
#   'teacherlastname_t': 'Tesfayohannes'},
#  {'averageratingscore_rf': 4.18,
#   'pk_id': 211870,
#   'total_number_of_ratings_i': 48,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Kathleen',
#   'teacherlastname_t': 'Nolan'},
#  {'averageratingscore_rf': 2.79,
#   'pk_id': 648154,
#   'total_number_of_ratings_i': 48,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Nada',
#   'teacherlastname_t': 'Al Masri'},
#  {'averageratingscore_rf': 2.7,
#   'pk_id': 956454,
#   'total_number_of_ratings_i': 48,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Chaitanya',
#   'teacherlastname_t': 'Swamy'},
#  {'averageratingscore_rf': 4.8,
#   'pk_id': 2041546,
#   'total_number_of_ratings_i': 48,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Ryan',
#   'teacherlastname_t': 'Trelford'},
#  {'averageratingscore_rf': 3.9,
#   'pk_id': 14864,
#   'total_number_of_ratings_i': 48,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Kathryn',
#   'teacherlastname_t': 'Hare'},
#  {'averageratingscore_rf': 3.8,
#   'pk_id': 173303,
#   'total_number_of_ratings_i': 48,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Catherine',
#   'teacherlastname_t': 'Briggs'},
#  {'averageratingscore_rf': 2.9,
#   'pk_id': 11078,
#   'total_number_of_ratings_i': 48,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Douglas',
#   'teacherlastname_t': 'Brown'},
#  {'averageratingscore_rf': 4.3,
#   'pk_id': 72644,
#   'total_number_of_ratings_i': 48,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Brian',
#   'teacherlastname_t': 'Ingalls'},
#  {'averageratingscore_rf': 2.35,
#   'pk_id': 9989,
#   'total_number_of_ratings_i': 47,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'David',
#   'teacherlastname_t': 'Carter'},
#  {'averageratingscore_rf': 4.64,
#   'pk_id': 10489,
#   'total_number_of_ratings_i': 47,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Gabriele',
#   'teacherlastname_t': 'Niccoli'},
#  {'averageratingscore_rf': 3.5,
#   'pk_id': 12449,
#   'total_number_of_ratings_i': 47,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Small',
#   'teacherlastname_t': 'Christopher'},
#  {'averageratingscore_rf': 2.55,
#   'pk_id': 24302,
#   'total_number_of_ratings_i': 47,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Jeanne Kay',
#   'teacherlastname_t': 'Guelke'},
#  {'averageratingscore_rf': 4.46,
# ...
#   'teacherfirstname_t': 'Tamas',
#   'teacherlastname_t': 'Horvath'},
#  {'averageratingscore_rf': 4.3,
#   'pk_id': 366162,
#   'total_number_of_ratings_i': 16,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Barry',
#   'teacherlastname_t': 'Warner'},
#  {'averageratingscore_rf': 3.31,
#   'pk_id': 31144,
#   'total_number_of_ratings_i': 16,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Magdy',
#   'teacherlastname_t': 'Salama'},
#  {'averageratingscore_rf': 4.41,
#   'pk_id': 32312,
#   'total_number_of_ratings_i': 16,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Doug',
#   'teacherlastname_t': 'Kirton'},
#  {'averageratingscore_rf': 4.2,
#   'pk_id': 1716041,
#   'total_number_of_ratings_i': 16,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Florian',
#   'teacherlastname_t': 'Girelli'},
#  {'averageratingscore_rf': 4.2,
#   'pk_id': 651756,
#   'total_number_of_ratings_i': 16,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Pascal',
#   'teacherlastname_t': 'Poupart'},
#  {'averageratingscore_rf': 4.7,
#   'pk_id': 2100367,
#   'total_number_of_ratings_i': 16,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Rob',
#   'teacherlastname_t': 'Hackman'},
#  {'averageratingscore_rf': 3.8,
#   'pk_id': 1106454,
#   'total_number_of_ratings_i': 16,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Uzma',
#   'teacherlastname_t': 'Rehman'},
#  {'averageratingscore_rf': 3.5,
#   'pk_id': 65632,
#   'total_number_of_ratings_i': 16,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Kieran',
#   'teacherlastname_t': 'Bonner'},
#  {'averageratingscore_rf': 3.0,
#   'pk_id': 1151783,
#   'total_number_of_ratings_i': 16,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Alain-Desire',
#   'teacherlastname_t': 'Nimubona'},
#  {'averageratingscore_rf': 3.6,
#   'pk_id': 220256,
#   'total_number_of_ratings_i': 16,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Robert',
#   'teacherlastname_t': 'Gibson'},
#  {'averageratingscore_rf': 2.8,
#   'pk_id': 596366,
#   'total_number_of_ratings_i': 16,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Kate',
#   'teacherlastname_t': 'Larson'},
#  {'averageratingscore_rf': 5.0,
#   'pk_id': 2101176,
#   'total_number_of_ratings_i': 16,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Megan',
#   'teacherlastname_t': 'McCarthy'},
#  {'averageratingscore_rf': 4.07,
#   'pk_id': 13695,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Anu',
#   'teacherlastname_t': 'Banerji'},
#  {'averageratingscore_rf': 3.9,
#   'pk_id': 13956,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'David',
#   'teacherlastname_t': 'Weckman'},
#  {'averageratingscore_rf': 2.7,
#   'pk_id': 14029,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Sherry',
#   'teacherlastname_t': 'Schiff'},
#  {'averageratingscore_rf': 4.27,
#   'pk_id': 14465,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'David',
#   'teacherlastname_t': 'Siegel'},
#  {'averageratingscore_rf': 3.17,
#   'pk_id': 30412,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Bill',
#   'teacherlastname_t': 'Chesney'},
#  {'averageratingscore_rf': 1.7,
#   'pk_id': 33166,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Holger',
#   'teacherlastname_t': 'Kleinke'},
#  {'averageratingscore_rf': 4.9,
#   'pk_id': 42254,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Dan',
#   'teacherlastname_t': 'Andreae'},
#  {'averageratingscore_rf': 3.5,
#   'pk_id': 59190,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Allan',
#   'teacherlastname_t': 'Plumtree'},
#  {'averageratingscore_rf': 3.6,
#   'pk_id': 59624,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Delbert',
#   'teacherlastname_t': 'Russell'},
#  {'averageratingscore_rf': 4.37,
#   'pk_id': 60923,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Wing-Ki',
#   'teacherlastname_t': 'Liu'},
#  {'averageratingscore_rf': 3.6,
#   'pk_id': 128633,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Michael',
#   'teacherlastname_t': 'Fowler'},
#  {'averageratingscore_rf': 4.1,
#   'pk_id': 173346,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Barbara',
#   'teacherlastname_t': 'Swartzentruber'},
#  {'averageratingscore_rf': 3.5,
#   'pk_id': 424071,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Bae-Yeun',
#   'teacherlastname_t': 'Ha'},
#  {'averageratingscore_rf': 3.47,
#   'pk_id': 627728,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Sandra',
#   'teacherlastname_t': 'Bullock'},
#  {'averageratingscore_rf': 3.0,
#   'pk_id': 641625,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Carolyn',
#   'teacherlastname_t': 'Ren'},
#  {'averageratingscore_rf': 3.2,
#   'pk_id': 652343,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Dale',
#   'teacherlastname_t': 'Henneke'},
#  {'averageratingscore_rf': 2.6,
#   'pk_id': 776935,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Guy',
#   'teacherlastname_t': 'Guillemette'},
#  {'averageratingscore_rf': 2.9,
#   'pk_id': 1262533,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Zhu "Joe"',
#   'teacherlastname_t': 'Qian'},
#  {'averageratingscore_rf': 4.7,
#   'pk_id': 1279802,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Andrew',
#   'teacherlastname_t': 'Faulkner'},
#  {'averageratingscore_rf': 3.2,
#   'pk_id': 1295696,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Lilia',
#   'teacherlastname_t': 'Krivodonova'},
#  {'averageratingscore_rf': 3.3,
#   'pk_id': 1405090,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Marybeth',
#   'teacherlastname_t': 'White'},
#  {'averageratingscore_rf': 3.8,
#   'pk_id': 1689665,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Laura',
#   'teacherlastname_t': 'Marrone'},
#  {'averageratingscore_rf': 4.3,
#   'pk_id': 1709988,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Eric',
#   'teacherlastname_t': 'Katz'},
#  {'averageratingscore_rf': 4.0,
#   'pk_id': 1712964,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Jennifer',
#   'teacherlastname_t': 'Liu'},
#  {'averageratingscore_rf': 2.8,
#   'pk_id': 1806638,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Loula',
#   'teacherlastname_t': 'Abd-Elrazak'},
#  {'averageratingscore_rf': 3.5,
#   'pk_id': 2072377,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Alain',
#   'teacherlastname_t': 'Gamache'},
#  {'averageratingscore_rf': 3.9,
#   'pk_id': 765426,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Ken',
#   'teacherlastname_t': 'Hirschkop'},
#  {'averageratingscore_rf': 2.6,
#   'pk_id': 1454515,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Olivia',
#   'teacherlastname_t': 'Mesta'},
#  {'averageratingscore_rf': 4.6,
#   'pk_id': 1848477,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Michael',
#   'teacherlastname_t': 'Wood'},
#  {'averageratingscore_rf': 3.0,
#   'pk_id': 1260458,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Michael',
#   'teacherlastname_t': 'Tam'},
#  {'averageratingscore_rf': 3.4,
#   'pk_id': 2172287,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Anna',
#   'teacherlastname_t': 'Purkey'},
#  {'averageratingscore_rf': 1.9,
#   'pk_id': 368458,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Kenneth',
#   'teacherlastname_t': 'McKay'},
#  {'averageratingscore_rf': 4.2,
#   'pk_id': 1453073,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Cecilia',
#   'teacherlastname_t': 'Cotton'},
#  {'averageratingscore_rf': 4.6,
#   'pk_id': 1499587,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Alastair Neil',
#   'teacherlastname_t': 'Craik'},
#  {'averageratingscore_rf': 3.8,
#   'pk_id': 1753243,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Andrew',
#   'teacherlastname_t': 'Laing'},
#  {'averageratingscore_rf': 2.8,
#   'pk_id': 1788840,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Christopher',
#   'teacherlastname_t': 'Lowry'},
#  {'averageratingscore_rf': 1.9,
#   'pk_id': 103258,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'David A.',
#   'teacherlastname_t': 'Johnson'},
#  {'averageratingscore_rf': 2.1,
#   'pk_id': 299167,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Gerry',
#   'teacherlastname_t': 'Schneider'},
#  {'averageratingscore_rf': 3.0,
#   'pk_id': 2089253,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Ryan',
#   'teacherlastname_t': 'Browne'},
#  {'averageratingscore_rf': 4.5,
#   'pk_id': 2071927,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Alfred',
#   'teacherlastname_t': 'Yu'},
#  {'averageratingscore_rf': 3.0,
#   'pk_id': 1531509,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Noura',
#   'teacherlastname_t': 'Limam'},
#  {'averageratingscore_rf': 3.3,
#   'pk_id': 1753851,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Lei Lei',
#   'teacherlastname_t': 'Zeng'},
#  {'averageratingscore_rf': 1.53,
#   'pk_id': 2310576,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Zamal',
#   'teacherlastname_t': 'Ruffudeen'},
#  {'averageratingscore_rf': 3.2,
#   'pk_id': 2341477,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Emily',
#   'teacherlastname_t': 'Kozlowski'},
#  {'averageratingscore_rf': 3.3,
#   'pk_id': 30245,
#   'total_number_of_ratings_i': 15,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Eric',
#   'teacherlastname_t': 'Haldenby'},
#  {'averageratingscore_rf': 3.04,
#   'pk_id': 9819,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'En-Hui',
#   'teacherlastname_t': 'Yang'},
#  {'averageratingscore_rf': 4.21,
#   'pk_id': 9847,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Anthony',
#   'teacherlastname_t': 'Vannelli'},
#  {'averageratingscore_rf': 2.93,
#   'pk_id': 14021,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Katherine',
#   'teacherlastname_t': 'La Hay'},
#  {'averageratingscore_rf': 4.93,
#   'pk_id': 15696,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Robert',
#   'teacherlastname_t': 'Ryan'},
#  {'averageratingscore_rf': 4.4,
#   'pk_id': 50608,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Monica B',
#   'teacherlastname_t': 'Emelko'},
#  {'averageratingscore_rf': 3.93,
#   'pk_id': 73251,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Vinko',
#   'teacherlastname_t': 'Grubisic'},
#  {'averageratingscore_rf': 2.07,
#   'pk_id': 111922,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Melanie',
#   'teacherlastname_t': 'Campbell'},
#  {'averageratingscore_rf': 2.18,
#   'pk_id': 240748,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Val',
#   'teacherlastname_t': 'Rynnimeri'},
#  {'averageratingscore_rf': 4.89,
#   'pk_id': 344781,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Rimma',
#   'teacherlastname_t': 'Volynska'},
#  {'averageratingscore_rf': 3.57,
#   'pk_id': 427477,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'C',
#   'teacherlastname_t': 'Devaud'},
#  {'averageratingscore_rf': 3.5,
#   'pk_id': 445067,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Guy',
#   'teacherlastname_t': 'Poirier'},
#  {'averageratingscore_rf': 2.1,
#   'pk_id': 536156,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Michael',
#   'teacherlastname_t': 'Mayer'},
#  {'averageratingscore_rf': 2.64,
#   'pk_id': 588684,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Mike',
#   'teacherlastname_t': 'Leamen'},
#  {'averageratingscore_rf': 2.5,
#   'pk_id': 853373,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Paulo',
#   'teacherlastname_t': 'Alencar'},
#  {'averageratingscore_rf': 3.8,
#   'pk_id': 900305,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Tracy',
#   'teacherlastname_t': 'Finn'},
#  {'averageratingscore_rf': 3.9,
#   'pk_id': 950138,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'David',
#   'teacherlastname_t': 'Moscovitch'},
#  {'averageratingscore_rf': 3.71,
#   'pk_id': 1031417,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Diana',
#   'teacherlastname_t': 'Chisholm'},
#  {'averageratingscore_rf': 4.21,
#   'pk_id': 1087806,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Tom',
#   'teacherlastname_t': 'Vance'},
#  {'averageratingscore_rf': 3.11,
#   'pk_id': 1216390,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Hui',
#   'teacherlastname_t': 'Huang'},
#  {'averageratingscore_rf': 2.68,
#   'pk_id': 1273071,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Binyamin',
#   'teacherlastname_t': 'Mantin'},
#  {'averageratingscore_rf': 4.71,
#   'pk_id': 1383626,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Osnat',
#   'teacherlastname_t': 'Lifshitz'},
#  {'averageratingscore_rf': 4.2,
#   'pk_id': 1401291,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Dinghai',
#   'teacherlastname_t': 'XU'},
#  {'averageratingscore_rf': 1.75,
#   'pk_id': 1478132,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Alexander',
#   'teacherlastname_t': 'Brenning'},
#  {'averageratingscore_rf': 4.8,
#   'pk_id': 1485502,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Katherine',
#   'teacherlastname_t': 'White'},
#  {'averageratingscore_rf': 3.5,
#   'pk_id': 1566516,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'David-Antoine',
#   'teacherlastname_t': 'Williams'},
#  {'averageratingscore_rf': 4.0,
#   'pk_id': 1669376,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Clifford',
#   'teacherlastname_t': 'Blake'},
#  {'averageratingscore_rf': 3.14,
#   'pk_id': 1746988,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Sharmistha',
#   'teacherlastname_t': 'Nag'},
#  {'averageratingscore_rf': 3.21,
#   'pk_id': 1793859,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Nicholas',
#   'teacherlastname_t': 'Ray'},
#  {'averageratingscore_rf': 2.54,
#   'pk_id': 1865379,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Arshi',
#   'teacherlastname_t': 'Shaikh'},
#  {'averageratingscore_rf': 3.0,
#   'pk_id': 1887616,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Kim',
#   'teacherlastname_t': 'Nguyen'},
#  {'averageratingscore_rf': 4.1,
#   'pk_id': 1907655,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Carolyn',
#   'teacherlastname_t': 'Knoll'},
#  {'averageratingscore_rf': 3.8,
#   'pk_id': 1916883,
#   'total_number_of_ratings_i': 14,
#   'schoolid_s': '1490',
#   'teacherfirstname_t': 'Joyce',
#   'teacherlastname_t': 'Tian'},
#  ...]

# %%
stmts_ratemyprofs = []
set_ratemyprofs = set()

for p in profs:
    if  'teacherfirstname_t' in p \
    and 'teacherlastname_t' in p \
    and 'averageratingscore_rf' in p \
    and 'total_number_of_ratings_i' in p \
    and 'pk_id' in p:
        
        first = sqlstr(p['teacherfirstname_t'])
        last = sqlstr(p['teacherlastname_t'])
        
        if (first, last) not in set_ratemyprofs:
            
            set_ratemyprofs.add((first, last))   
            stmts_ratemyprofs.append(
                f"""INSERT INTO rateMyProfRecord (firstName, lastName, averageRating, numbersOfRatings, website) 
                    VALUES ({first}, {last}, {p['averageratingscore_rf']}, {p['total_number_of_ratings_i']},
                            'https://www.ratemyprofessors.com/ShowRatings.jsp?tid={p['pk_id']}');"""
            )

# %% [markdown]
# ### Output to Files

# %%
with open('insert_1_faculty.sql', 'w+') as f:
    for line in stmts_faculty:
        f.write(line + '\n')

# %%
with open('insert_2_subject.sql', 'w+') as f:
    for line in stmts_subject:
        f.write(line + '\n')

# %%
with open('insert_3_course.sql', 'w+') as f:
    for line in stmts_course:
        f.write(line + '\n')

# %%
with open('insert_4_term.sql', 'w+') as f:
    for line in stmts_term:
        f.write(line + '\n')

# %%
with open('insert_5_courseOffering.sql', 'w+') as f:
    for line in stmts_courseOffering:
        f.write(line + '\n')

# %%
with open('insert_6_prerequisite.sql', 'w+') as f:
    for line in stmts_prerequisite:
        f.write(line + "\n")

# %%
with open('insert_8_rateMyProfRecords.sql', 'w+') as f:
    for line in stmts_ratemyprofs:
        f.write(line + "\n")

# %% [markdown]
# ### Export Course.txt

# %%
with open('course.txt', 'w+') as f:
    for line in set_course:
        f.write(line + '\n')
