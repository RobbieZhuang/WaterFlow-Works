# %%
import requests
import json
import pickle

from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# %%
def g(url):
    
    with requests.Session() as s:
        retries = Retry(total=10, backoff_factor=1, status_forcelist=[500, 502, 503, 504])

        s.mount('http://', HTTPAdapter(max_retries=retries))
        s.mount('https://', HTTPAdapter(max_retries=retries))

        return s.get(url, timeout=10)

# %%
sqlstr = lambda string: "'" + str(string).replace("'", "''") + "'"

# %% [markdown]
# ### Results

# %%
## SQL create statements
stmts_faculty = [] # done
stmts_degree = []
stmts_subject = [] # done
stmts_course = [] # done
stmts_courseGroup = []
stmts_courseGroupMember = []
stmts_prerequisite = []
stmts_degreeRequirement = []
stmts_term = [] # done
stmts_courseOffering = [] # done

# %%
## Entity Sets for Later Use
set_faculty = set()
set_subject = set()
set_course = set()
set_courseOffering = set()

# %% [markdown]
# ### Term

# %%
## strings for terms
terms = [str(100 + y) + str(t) for y in range (10, 21) for t in [1, 5, 9]]

# %%
stmts_term = [f'INSERT INTO term (code) VALUES ({term});' for term in terms]

# %% [markdown]
# ### Faculty

# %%
with open('faculty.json', 'r') as faculty_f:
    faculties = json.load(faculty_f)

# %%
set_faculty = set()
stmts_faculty = []

for faculty in faculties:
    title = faculty['group_code']
    short_name = faculty['group_short_name']
    full_name = faculty['group_full_name']
    
    set_faculty.add(title)
    stmts_faculty.append(
        "INSERT INTO faculty (title, shortName, fullName) VALUES (%s, %s, %s);" % 
        (sqlstr(title), sqlstr(short_name), sqlstr(full_name))
    )

# %% [markdown]
# ### Subject

# %%
with open('subject.json', 'r') as subject_f:
  subjects = json.load(subject_f)

# %%
set_subject = set()
stmts_subject = []

for subject in subjects:
    title = subject['subject']
    desc = subject['description']
    faculty = subject['group']
    
    if faculty in set_faculty:
        set_subject.add(title)
        stmts_subject.append(
            "INSERT INTO subject (title, facultyTitle, description) VALUES (%s, %s, %s);" % 
            (sqlstr(title), sqlstr(faculty), sqlstr(desc))
        )

# %% [markdown]
# ### Courses

# %% [markdown]
# #### You can import the courses from `course.txt` if the file exists.

# %%
set_course = set()
with open('course.txt', 'r') as f:
    for line in f:
        set_course.add(line.strip())

# %% [markdown]
# #### Alternatively, you can scrape the course data from the OpenAPI as well.

# %%
courses_r = g('https://api.uwaterloo.ca/v2/courses.json?key=e5c5ea41b7715202b2846b04b286f29d')
courses = list(filter(lambda c: '`' not in c['catalog_number'], courses_r.json()['data'])) # there is a "GER 744`"

# %%
set_course = set()
stmts_course = []

l = len(courses)

for i, c in enumerate(courses):
    subject_title = c['subject']
    catalog_number = c['catalog_number']
    
    course_code = subject_title + ' ' + catalog_number
    
    ## print the progress of processing
    print('%s/%s course(s) processed. Processing %s.\t\t' % (i, l, course_code), end='\r', flush=True)

    course_detail_r = g(
        'https://api.uwaterloo.ca/v2/courses/%s/%s.json?key=e5c5ea41b7715202b2846b04b286f29d' %
        (subject_title, catalog_number)
    ).json()

    if 'data' in course_detail_r and course_detail_r['data'] and subject_title in set_subject:
        course_detail = course_detail_r['data']

        title = course_detail['title']
        credit = course_detail['units']
        desc = course_detail['description']
        course_types = ', '.join(ins for ins in course_detail['instructions'])

        set_course.add(course_code)
        stmts_course.append(
            "INSERT INTO course (courseCode, title, credit, courseTypes, description, subjectTitle) VALUES (%s, %s, %s, %s, %s, %s);" %
            (sqlstr(course_code),
             sqlstr(title),
             credit,
             sqlstr(course_types),
             sqlstr(desc),
             sqlstr(subject_title))
        )
        
print('\ndone.')
# Out:
# 7448/7449 course(s) processed. Processing SYDE 263.				k.
# done.

# %% [markdown]
# ### Course Offerings

# %%
set_courseOffering = set()
stmts_courseOffering = []

l = len(set_subject)
l_terms = len(terms)

for i, subject_title in enumerate(set_subject):
    
    for j, term in enumerate(terms):
        
        ## print the progress of processing
        print('%s/%s terms out of %s/%s subject(s) processed. Processing term=%s, subject=%s. So far %s offering(s) recorded.\t\t' %
              (j, l_terms, i, l, term, subject_title, len(stmts_courseOffering)), end='\r', flush=True)
            
        offerings_r = g(
            'https://api.uwaterloo.ca/v2/terms/%s/%s/schedule.json?key=e5c5ea41b7715202b2846b04b286f29d' %
            (term, subject_title)
        ).json()
                
        if 'data' in offerings_r and offerings_r['data']:
            offerings = offerings_r['data']

            for offering in offerings:
                catalog_number = offering['catalog_number']
                course_code = subject_title + ' ' + catalog_number

                if course_code in set_course:
                    args = []
                    vals = []

                    args.append('courseCode')
                    vals.append(sqlstr(course_code))

                    args.append('termCode')
                    vals.append(term)

                    section = offering['section'].split(' ')

                    courseType = section[0]
                    component = section[1]
                    
                    if (course_code, term, component) not in set_courseOffering:
                        args.append('courseType')
                        vals.append(sqlstr(courseType))

                        args.append('component')
                        vals.append(component)

                        if offering['related_component_1']:
                            args.append('relatedComponent1')
                            vals.append(str(offering['related_component_1']))

                        if offering['related_component_2']:
                            args.append('relatedComponent2')
                            vals.append(str(offering['related_component_2']))

                        enrlCap = offering['enrollment_capacity']
                        enrlTot = offering['enrollment_total']

                        args.append('enrlCap')
                        vals.append(str(enrlCap))

                        args.append('enrlTot')
                        vals.append(str(enrlTot))

                        classes = offering['classes']
                        if classes:
                            cls = classes[0]

                            instructors = cls['instructors']
                            if instructors:
                                prof = instructors[0].split(',')

                                if len(prof) > 1:
                                    args.append('profFirstName')
                                    vals.append(sqlstr(prof[1]))

                                args.append('profLastName')
                                vals.append(sqlstr(prof[0]))

                            clsDate = cls['date']
                            if clsDate:
                                if clsDate['start_time']:
                                    args.append('classStartTime')
                                    vals.append(sqlstr(clsDate['start_time']))

                                if clsDate['end_time']:
                                    args.append('classEndTime')
                                    vals.append(sqlstr(clsDate['end_time']))

                                if clsDate['weekdays']:
                                    args.append('classWeekdays')
                                    vals.append(sqlstr(clsDate['weekdays']))

                            loc = cls['location']
                            if loc:
                                if loc['building']:
                                    args.append('classBuilding')
                                    vals.append(sqlstr(loc['building']))

                                if loc['room']:
                                    args.append('classRoom')
                                    vals.append(sqlstr(loc['room']))

                        set_courseOffering.add((course_code, term, component))
                        stmts_courseOffering.append(
                            f"INSERT INTO courseOffering ({', '.join(args)}) VALUES ({', '.join(vals)});"
                        )
                    
print('\ndone.')
# Out:
# 32/33 terms out of 206/207 subject(s) processed. Processing term=1209, subject=UNIV. So far 90964 offering(s) recorded.
# done.

# %% [markdown]
# ### Course Prereqs

# %%
prereq_endpoint = "https://api.uwaterloo.ca/v2/courses/{}/{}/prerequisites.json?key=e5c5ea41b7715202b2846b04b286f29d&fbclid=IwAR26szkbPavfEMNVDdLaYTznyHkCz8imaQ7PrAd8fUmG2WSjXJiew6kuFsw"

for i, course in enumerate(courses):
    subject = course['subject']
    num = course['catalog_number']
    
    course['prerequisites_parsed'] = []
    course_endpoint = prereq_endpoint.format(subject, num)
    
    print("Finding prereqs for {} {} ({}/{}) \t\t".format(subject, num, i, len(courses)), end="\r", flush=True)
    
    r = g(course_endpoint)
    while r.status_code != 200:
        # Test for request error
        print("ERROR!")
        r = g(course_endpoint)
        
    info = r.json()
    status = info['meta']['status']
    
    # Test for API error
    if status == 204:
        # No data returned
        continue
    elif status == 200: 
        # Found prereqs
        if "data" in info:
            course['prerequisites_parsed'] = info['data']['prerequisites_parsed']
    else:
        print("ERROR: got status {}".format(info['status']))
        
print('\ndone.')
# Out:
# Finding prereqs for SYDE 263 (7448/7449) 				)
# done.

# %%
# Save them just in case the next step messes them up
pickle.dump(courses, open("courses_with_prereqs.pckl", "wb"))

# %%
courses = pickle.load(open("courses_with_prereqs.pckl", 'rb'))

# %%
courses
# Out:
# [{'course_id': '011672',
#   'subject': 'ACC',
#   'catalog_number': '604',
#   'title': 'Statutory Interpretation',
#   'prerequisites_parsed': []},
#  {'course_id': '011673',
#   'subject': 'ACC',
#   'catalog_number': '605',
#   'title': 'International Tax',
#   'prerequisites_parsed': []},
#  {'course_id': '011674',
#   'subject': 'ACC',
#   'catalog_number': '606',
#   'title': 'Business Valuations',
#   'prerequisites_parsed': []},
#  {'course_id': '011675',
#   'subject': 'ACC',
#   'catalog_number': '607',
#   'title': 'Tax Issues Integration',
#   'prerequisites_parsed': []},
#  {'course_id': '011677',
#   'subject': 'ACC',
#   'catalog_number': '609',
#   'title': 'Financial Statement Analysis',
#   'prerequisites_parsed': []},
#  {'course_id': '000003',
#   'subject': 'ACC',
#   'catalog_number': '610',
#   'title': 'Public Accounting Practice',
#   'prerequisites_parsed': []},
#  {'course_id': '000004',
#   'subject': 'ACC',
#   'catalog_number': '611',
#   'title': 'External Reporting',
#   'prerequisites_parsed': []},
#  {'course_id': '011484',
#   'subject': 'ACC',
#   'catalog_number': '621',
#   'title': 'System Reliability Principles and Criteria',
#   'prerequisites_parsed': []},
#  {'course_id': '011478',
#   'subject': 'ACC',
#   'catalog_number': '622',
#   'title': 'Electronic Commerce',
#   'prerequisites_parsed': []},
#  {'course_id': '011479',
#   'subject': 'ACC',
#   'catalog_number': '623',
#   'title': 'Business Technology Law',
#   'prerequisites_parsed': []},
#  {'course_id': '000012',
#   'subject': 'ACC',
#   'catalog_number': '626',
#   'title': 'IT Assurance and Computer-Assisted Audit Techniques',
#   'prerequisites_parsed': []},
#  {'course_id': '000013',
#   'subject': 'ACC',
#   'catalog_number': '627',
#   'title': 'Business Process Enablement and Project Management',
#   'prerequisites_parsed': []},
#  {'course_id': '000020',
#   'subject': 'ACC',
#   'catalog_number': '650',
#   'title': 'Assurance and Governance',
#   'prerequisites_parsed': []},
#  {'course_id': '013326',
#   'subject': 'ACC',
#   'catalog_number': '652',
#   'title': 'Forensic Accounting',
#   'prerequisites_parsed': []},
#  {'course_id': '000024',
#   'subject': 'ACC',
#   'catalog_number': '662',
#   'title': 'Tax Policy',
#   'prerequisites_parsed': []},
#  {'course_id': '000028',
#   'subject': 'ACC',
#   'catalog_number': '680',
#   'title': 'Performance Measurement and Control systems for Implementing Strategy',
#   'prerequisites_parsed': []},
#  {'course_id': '000029',
#   'subject': 'ACC',
#   'catalog_number': '681',
#   'title': 'Understanding and Managing Organizational Change',
#   'prerequisites_parsed': []},
#  {'course_id': '010147',
#   'subject': 'ACC',
#   'catalog_number': '682',
#   'title': 'Measuring and Managing the Value Creation Process',
#   'prerequisites_parsed': []},
#  {'course_id': '012014',
#   'subject': 'ACC',
#   'catalog_number': '683',
#   'title': 'Emerging Issues in Management and Marketing',
#   'prerequisites_parsed': []},
#  {'course_id': '013327',
#   'subject': 'ACC',
#   'catalog_number': '684',
#   'title': 'Strategy and Business Models',
#   'prerequisites_parsed': []},
#  {'course_id': '013328',
#   'subject': 'ACC',
#   'catalog_number': '685',
#   'title': 'Performance Management',
#   'prerequisites_parsed': []},
#  {'course_id': '000030',
#   'subject': 'ACC',
#   'catalog_number': '690',
#   'title': 'Topics in Accounting',
#   'prerequisites_parsed': []},
#  {'course_id': '000040',
#   'subject': 'ACC',
#   'catalog_number': '701',
#   'title': 'Financial Accounting Research Seminar',
#   'prerequisites_parsed': []},
#  {'course_id': '000041',
#   'subject': 'ACC',
#   'catalog_number': '702',
#   'title': 'Management Accounting Research Seminar',
#   'prerequisites_parsed': []},
#  {'course_id': '000042',
#   'subject': 'ACC',
#   'catalog_number': '750',
#   'title': 'Auditing Research Seminar',
#   'prerequisites_parsed': []},
#  {'course_id': '000043',
#   'subject': 'ACC',
#   'catalog_number': '760',
#   'title': 'Taxation Research Seminar',
#   'prerequisites_parsed': []},
#  {'course_id': '000044',
#   'subject': 'ACC',
#   'catalog_number': '770',
#   'title': 'Finance 1',
#   'prerequisites_parsed': []},
#  {'course_id': '000045',
#   'subject': 'ACC',
#   'catalog_number': '771',
#   'title': 'Finance 2',
#   'prerequisites_parsed': []},
#  {'course_id': '000046',
#   'subject': 'ACC',
#   'catalog_number': '772',
#   'title': 'Finance 3',
#   'prerequisites_parsed': []},
#  {'course_id': '000047',
#   'subject': 'ACC',
#   'catalog_number': '781',
#   'title': 'Introduction to Research 1',
#   'prerequisites_parsed': []},
#  {'course_id': '000049',
#   'subject': 'ACC',
#   'catalog_number': '784',
#   'title': 'Selected Topics in Research Methodology',
#   'prerequisites_parsed': []},
#  {'course_id': '003290',
#   'subject': 'ACTSC',
#   'catalog_number': '221',
#   'title': 'Introductory Financial Mathematics (Non-Specialist Level)',
#   'prerequisites_parsed': ''},
#  {'course_id': '003293',
#   'subject': 'ACTSC',
#   'catalog_number': '231',
#   'title': 'Introductory Financial Mathematics',
#   'prerequisites_parsed': [[1, 'MATH137', 'MATH147'],
#    [1, 'STAT220', 'STAT230', 'STAT240'],
#    [1, 'ACTSC232']]},
#  {'course_id': '003294',
#   'subject': 'ACTSC',
#   'catalog_number': '232',
#   'title': 'Life Contingencies 1',
#   'prerequisites_parsed': ['ACTSC231',
#    [1, 'STAT230', 'STAT240'],
#    [1, 'MTHEL131N', 'ACTSC331']]},
#  {'course_id': '011750',
#   'subject': 'ACTSC',
#   'catalog_number': '291',
#   'title': 'Corporate Finance 1',
#   'prerequisites_parsed': [[1, 'MATH136', 'MATH146'],
#    [1, 'MATH138', 'MATH148']]},
#  {'course_id': '003295',
#   'subject': 'ACTSC',
#   'catalog_number': '331',
#   'title': 'Life Contingencies 2',
#   'prerequisites_parsed': ['ACTSC232']},
#  {'course_id': '011438',
#   'subject': 'ACTSC',
#   'catalog_number': '371',
#   'title': 'Introduction to Investments',
#   'prerequisites_parsed': ''},
#  {'course_id': '012044',
#   'subject': 'ACTSC',
#   'catalog_number': '372',
#   'title': 'Corporate Finance',
#   'prerequisites_parsed': ['ACTSC371', [1, 'MATH207', 'MATH237', 'MATH247']]},
#  {'course_id': '011751',
#   'subject': 'ACTSC',
#   'catalog_number': '391',
#   'title': 'Corporate Finance 2',
#   'prerequisites_parsed': [1, 'AFM272', 'ACTSC291']},
#  {'course_id': '003300',
#   'subject': 'ACTSC',
#   'catalog_number': '431',
#   'title': 'Loss Models 1',
#   'prerequisites_parsed': ['STAT330', 'STAT333']},
#  {'course_id': '003301',
#   'subject': 'ACTSC',
#   'catalog_number': '432',
#   'title': 'Loss Models 2',
#   'prerequisites_parsed': ['STAT330', 'STAT333']},
#  {'course_id': '003302',
#   'subject': 'ACTSC',
#   'catalog_number': '433',
#   'title': 'Analysis of Survival Data',
#   'prerequisites_parsed': ['ACTSC331', 'STAT330']},
#  {'course_id': '009492',
#   'subject': 'ACTSC',
#   'catalog_number': '445',
#   'title': 'Quantitative Enterprise Risk Management',
#   'prerequisites_parsed': [[1,
#     [1, 'AFM372', 'ACTSC391'],
#     ['ACTSC231', 'ACTSC371'],
#     'ACTSC231BUS'],
#    [1, ['STAT330', 'STAT333'], 'STAT334']]},
#  {'course_id': '003305',
#   'subject': 'ACTSC',
#   'catalog_number': '446',
#   'title': 'Mathematics of Financial Markets',
#   'prerequisites_parsed': [[1,
#     [1, 'AFM372', 'ACTSC391'],
#     'ACTSC231',
#     'ACTSC231BUS'],
#    [1, 'STAT333', 'STAT334']]},
#  {'course_id': '003308',
#   'subject': 'ACTSC',
#   'catalog_number': '453',
#   'title': 'Basic Pension Mathematics',
#   'prerequisites_parsed': ['ACTSC331']},
#  {'course_id': '013318',
#   'subject': 'ACTSC',
#   'catalog_number': '455',
#   'title': 'Advanced Life Insurance Practice',
#   'prerequisites_parsed': ['ACTSC331']},
#  {'course_id': '003312',
#   'subject': 'ACTSC',
#   'catalog_number': '462',
#   'title': 'Introduction to Property and Casualty Pricing',
#   'prerequisites_parsed': [1, [1, 'AFM272', 'ACTSC291'], 'ACTSC231']},
#  {'course_id': '003299',
#   'subject': 'ACTSC',
#   'catalog_number': '463',
#   'title': 'Introduction to Property and Casualty Loss Reserving',
#   'prerequisites_parsed': [[1, [1, 'AFM272', 'ACTSC291'], 'ACTSC231'],
#    [1, 'STAT331', 'STAT371', 'STAT373']]},
#  {'course_id': '014534',
#   'subject': 'ACTSC',
#   'catalog_number': '468',
#   'title': 'Readings in Actuarial Science 1',
#   'prerequisites_parsed': ''},
#  {'course_id': '014535',
#   'subject': 'ACTSC',
#   'catalog_number': '469',
#   'title': 'Readings in Actuarial Science 2',
#   'prerequisites_parsed': ''},
#  {'course_id': '011760',
#   'subject': 'ACTSC',
#   'catalog_number': '471',
#   'title': 'Advanced Corporate Finance',
#   'prerequisites_parsed': [1, [1, 'AFM372', 'ACTSC391'], 'ACTSC372']},
#  {'course_id': '013389',
#   'subject': 'ACTSC',
#   'catalog_number': '611',
#   'title': 'Financial Mathematics I',
#   'prerequisites_parsed': []},
#  {'course_id': '013390',
#   'subject': 'ACTSC',
#   'catalog_number': '612',
#   'title': 'Life Insurance Mathematics I',
#   'prerequisites_parsed': []},
#  {'course_id': '013391',
#   'subject': 'ACTSC',
#   'catalog_number': '613',
#   'title': 'Statistics for Actuarial Science',
#   'prerequisites_parsed': []},
#  {'course_id': '013392',
#   'subject': 'ACTSC',
#   'catalog_number': '614',
#   'title': 'Corporate Finance',
#   'prerequisites_parsed': []},
#  {'course_id': '013393',
#   'subject': 'ACTSC',
#   'catalog_number': '615',
#   'title': 'Economics',
#   'prerequisites_parsed': []},
#  {'course_id': '013406',
#   'subject': 'ACTSC',
#   'catalog_number': '621',
#   'title': 'Financial Mathematics II',
#   'prerequisites_parsed': ''},
#  {'course_id': '013395',
#   'subject': 'ACTSC',
#   'catalog_number': '622',
#   'title': 'Life Insurance Mathematics II',
#   'prerequisites_parsed': ''},
#  {'course_id': '013396',
#   'subject': 'ACTSC',
#   'catalog_number': '623',
#   'title': 'Applied Statistics',
#   'prerequisites_parsed': ''},
#  {'course_id': '013397',
#   'subject': 'ACTSC',
#   'catalog_number': '624',
#   'title': 'Stochastic Processes for Actuarial Science',
#   'prerequisites_parsed': ''},
#  {'course_id': '013398',
#   'subject': 'ACTSC',
#   'catalog_number': '625',
#   'title': 'Casualty and Health Insurance Mathematics',
#   'prerequisites_parsed': ''},
#  {'course_id': '013399',
#   'subject': 'ACTSC',
#   'catalog_number': '631',
#   'title': 'Financial Mathematics III',
#   'prerequisites_parsed': ''},
#  {'course_id': '013400',
#   'subject': 'ACTSC',
#   'catalog_number': '632',
#   'title': 'Life Insurance Mathematics III',
#   'prerequisites_parsed': ''},
#  {'course_id': '013401',
#   'subject': 'ACTSC',
#   'catalog_number': '633',
#   'title': 'Actuarial Risk Management',
#   'prerequisites_parsed': ''},
#  {'course_id': '013402',
#   'subject': 'ACTSC',
#   'catalog_number': '634',
#   'title': 'Quantitative Risk Management',
#   'prerequisites_parsed': ''},
#  {'course_id': '013403',
#   'subject': 'ACTSC',
#   'catalog_number': '635',
#   'title': 'Profession Communications in Actuarial Science',
#   'prerequisites_parsed': ''},
#  {'course_id': '009455',
#   'subject': 'ACTSC',
#   'catalog_number': '690',
#   'title': 'Literature & Research Studies',
#   'prerequisites_parsed': []},
#  {'course_id': '000071',
#   'subject': 'ACTSC',
#   'catalog_number': '831',
#   'title': 'Loss Models 1',
#   'prerequisites_parsed': []},
#  {'course_id': '000072',
#   'subject': 'ACTSC',
#   'catalog_number': '832',
#   'title': 'Loss Models 2',
#   'prerequisites_parsed': []},
#  {'course_id': '000073',
#   'subject': 'ACTSC',
#   'catalog_number': '833',
#   'title': 'Analysis of Mortality Data',
#   'prerequisites_parsed': []},
#  {'course_id': '010064',
#   'subject': 'ACTSC',
#   'catalog_number': '845',
#   'title': 'Quantitative Enterprise Risk Management',
#   'prerequisites_parsed': []},
#  {'course_id': '011270',
#   'subject': 'ACTSC',
#   'catalog_number': '846',
#   'title': 'Mathematics of Financial Markets',
#   'prerequisites_parsed': []},
#  {'course_id': '000076',
#   'subject': 'ACTSC',
#   'catalog_number': '853',
#   'title': 'Basic Pension Mathematics',
#   'prerequisites_parsed': []},
#  {'course_id': '000078',
#   'subject': 'ACTSC',
#   'catalog_number': '855',
#   'title': 'Advanced Life Insurance Practice',
#   'prerequisites_parsed': []},
#  {'course_id': '011273',
#   'subject': 'ACTSC',
#   'catalog_number': '862',
#   'title': 'Introduction to Property and Casualty Pricing',
#   'prerequisites_parsed': []},
#  {'course_id': '000080',
#   'subject': 'ACTSC',
#   'catalog_number': '863',
#   'title': 'Introduction fo Property and Casuality Loss Reserving',
#   'prerequisites_parsed': []},
#  {'course_id': '013085',
#   'subject': 'ACTSC',
#   'catalog_number': '936',
#   'title': 'Longitudinal Data Analysis',
#   'prerequisites_parsed': [[1, 'STAT431', 'STAT831'], 'STAT330']},
#  {'course_id': '000082',
#   'subject': 'ACTSC',
#   'catalog_number': '961',
#   'title': 'Mathematical Methods of Loss Reserving',
#   'prerequisites_parsed': []},
#  {'course_id': '011274',
#   'subject': 'ACTSC',
#   'catalog_number': '963',
#   'title': 'Insurance Surplus Mathematics',
#   'prerequisites_parsed': []},
#  {'course_id': '011275',
#   'subject': 'ACTSC',
#   'catalog_number': '964',
#   'title': 'Topics in Quantitative Risk Management',
#   'prerequisites_parsed': []},
#  {'course_id': '011276',
#   'subject': 'ACTSC',
#   'catalog_number': '965',
#   'title': 'Extreme Value Theory',
#   'prerequisites_parsed': []},
#  {'course_id': '011686',
#   'subject': 'ACTSC',
#   'catalog_number': '966',
#   'title': 'Aggregate Claims Models',
#   'prerequisites_parsed': [1, 'ACTS431', 'ACTS831']},
#  {'course_id': '000044',
#   'subject': 'ACTSC',
#   'catalog_number': '970',
#   'title': 'Finance 1',
#   'prerequisites_parsed': []},
#  {'course_id': '000045',
#   'subject': 'ACTSC',
#   'catalog_number': '971',
#   'title': 'Finance 2',
#   'prerequisites_parsed': []},
#  {'course_id': '000046',
#   'subject': 'ACTSC',
#   'catalog_number': '972',
#   'title': 'Finance 3',
#   'prerequisites_parsed': []},
#  {'course_id': '011622',
#   'subject': 'ACTSC',
#   'catalog_number': '973',
#   'title': 'Portfolio Optimization',
#   'prerequisites_parsed': []},
#  {'course_id': '014063',
#   'subject': 'ACTSC',
#   'catalog_number': '974',
#   'title': 'Financial Econometrics',
#   'prerequisites_parsed': []},
#  {'course_id': '000083',
#   'subject': 'ACTSC',
#   'catalog_number': '980',
#   'title': 'Social Insurance',
#   'prerequisites_parsed': []},
#  {'course_id': '000085',
#   'subject': 'ACTSC',
#   'catalog_number': '991',
#   'title': 'Topics in Actuarial Science',
#   'prerequisites_parsed': []},
#  {'course_id': '013227',
#   'subject': 'ADMGT',
#   'catalog_number': '601',
#   'title': 'Introduction to Financial and Managerial Accounting',
#   'prerequisites_parsed': []},
#  {'course_id': '000093',
#   'subject': 'ACTSC',
#   'catalog_number': '992',
#   'title': 'Seminar in Actuarial Science',
#   'prerequisites_parsed': []},
#  {'course_id': '011404',
#   'subject': 'AFM',
#   'catalog_number': '101',
#   'title': 'Introduction to Financial Accounting',
#   'prerequisites_parsed': ''},
#  {'course_id': '011700',
#   'subject': 'AFM',
#   'catalog_number': '102',
#   'title': 'Introduction to Managerial Accounting',
#   'prerequisites_parsed': [1, 'AFM101', [1, 'BUS127W', 'BUS227W']]},
#  {'course_id': '013719',
#   'subject': 'AFM',
#   'catalog_number': '121',
#   'title': 'Introduction to Global Financial Markets',
#   'prerequisites_parsed': ''},
#  {'course_id': '003239',
#   'subject': 'AFM',
#   'catalog_number': '123',
#   'title': 'Accounting Information for Managers',
#   'prerequisites_parsed': ''},
#  {'course_id': '003243',
#   'subject': 'AFM',
#   'catalog_number': '131',
#   'title': 'Introduction to Business in North America',
#   'prerequisites_parsed': ''},
#  {'course_id': '011411',
#   'subject': 'AFM',
#   'catalog_number': '201',
#   'title': 'Introduction to Professional Practice',
#   'prerequisites_parsed': ['AFM101']},
#  {'course_id': '013739',
#   'subject': 'AFM',
#   'catalog_number': '202',
#   'title': 'Introduction to Public Practice',
#   'prerequisites_parsed': ['AFM101']},
#  {'course_id': '013740',
#   'subject': 'AFM',
#   'catalog_number': '203',
#   'title': 'Introduction to Decision Support',
#   'prerequisites_parsed': ['AFM101']},
#  {'course_id': '013741',
#   'subject': 'AFM',
#   'catalog_number': '204',
#   'title': 'Introduction to Applied Finance',
#   'prerequisites_parsed': ['AFM121']},
#  {'course_id': '013742',
#   'subject': 'AFM',
#   'catalog_number': '211',
#   'title': 'Connections to Business Context',
#   'prerequisites_parsed': ['AFM101', 'AFM131', 'SPCOM111']},
#  {'course_id': '003247',
#   'subject': 'AFM',
#   'catalog_number': '231',
#   'title': 'Business Law',
#   'prerequisites_parsed': []},
#  {'course_id': '010334',
#   'subject': 'AFM',
#   'catalog_number': '241',
#   'title': 'Introduction to Business Information Technology',
#   'prerequisites_parsed': ['AFM102']},
#  {'course_id': '003257',
#   'subject': 'AFM',
#   'catalog_number': '271',
#   'title': 'Managerial Finance 1',
#   'prerequisites_parsed': [1, 'STAT211', 'STAT230', 'STAT240', 'ECON221']},
#  {'course_id': '011750',
#   'subject': 'AFM',
#   'catalog_number': '272',
#   'title': 'Corporate Finance 1',
#   'prerequisites_parsed': [[1, 'MATH128', 'MATH138', 'MATH148'],
#    [1, 'MATH136', 'MATH146']]},
#  {'course_id': '011413',
#   'subject': 'AFM',
#   'catalog_number': '432',
#   'title': 'Legal Environment and Corporate Governance',
#   'prerequisites_parsed': ''},
#  {'course_id': '003257',
#   'subject': 'AFM',
#   'catalog_number': '273',
#   'title': 'Managerial Finance 1',
#   'prerequisites_parsed': ['STAT211']},
#  {'course_id': '003258',
#   'subject': 'AFM',
#   'catalog_number': '274',
#   'title': 'Managerial Finance 2',
#   'prerequisites_parsed': ['AFM273']},
#  {'course_id': '013743',
#   'subject': 'AFM',
#   'catalog_number': '280',
#   'title': 'Introduction to Organizational Behaviour',
#   'prerequisites_parsed': ''},
#  {'course_id': '003253',
#   'subject': 'AFM',
#   'catalog_number': '291',
#   'title': 'Intermediate Financial Accounting 1',
#   'prerequisites_parsed': ['AFM101']},
#  {'course_id': '013744',
#   'subject': 'AFM',
#   'catalog_number': '311',
#   'title': 'Connections to Ethical Context',
#   'prerequisites_parsed': ['AFM211']},
#  {'course_id': '013726',
#   'subject': 'AFM',
#   'catalog_number': '321',
#   'title': 'Personal Financial Planning',
#   'prerequisites_parsed': [1,
#    [1, 'AFM274', 'AFM371'],
#    [1, 'AFM372', 'ACTSC391']]},
#  {'course_id': '011702',
#   'subject': 'AFM',
#   'catalog_number': '322',
#   'title': 'Derivative Securities',
#   'prerequisites_parsed': [1,
#    [1, 'AFM274', 'AFM371'],
#    [1, 'AFM372', 'ACTSC391']]},
#  {'course_id': '013727',
#   'subject': 'AFM',
#   'catalog_number': '323',
#   'title': 'Quantitative Foundations for Finance',
#   'prerequisites_parsed': [1, 'AFM274', 'AFM371']},
#  {'course_id': '014473',
#   'subject': 'AFM',
#   'catalog_number': '328',
#   'title': 'Investment Management - Junior Analyst',
#   'prerequisites_parsed': ''},
#  {'course_id': '014474',
#   'subject': 'AFM',
#   'catalog_number': '329',
#   'title': 'Investment Management - Senior Analyst',
#   'prerequisites_parsed': [1, 'AFM274', [1, 'AFM372', 'ACTSC391']]},
#  {'course_id': '003269',
#   'subject': 'AFM',
#   'catalog_number': '331',
#   'title': 'Business Strategy',
#   'prerequisites_parsed': [[1,
#     [1, 'AFM271', 'AFM273'],
#     [1, 'AFM272', 'ACTSC291']],
#    'AFM291']},
#  {'course_id': '011974',
#   'subject': 'AFM',
#   'catalog_number': '332',
#   'title': 'Accounting, Assurance, and the Law',
#   'prerequisites_parsed': [[1, ['AFM101', 'AFM102'], 'AFM123'],
#    [1, 'AFM231', 'LS283']]},
#  {'course_id': '012769',
#   'subject': 'AFM',
#   'catalog_number': '333',
#   'title': 'International Business',
#   'prerequisites_parsed': [1, 'AFM131', 'ARBUS101']},
#  {'course_id': '003273',
#   'subject': 'AFM',
#   'catalog_number': '341',
#   'title': 'Accounting Information Systems',
#   'prerequisites_parsed': ''},
#  {'course_id': '003275',
#   'subject': 'AFM',
#   'catalog_number': '351',
#   'title': 'Audit Strategy',
#   'prerequisites_parsed': ['AFM391']},
#  {'course_id': '003278',
#   'subject': 'AFM',
#   'catalog_number': '352',
#   'title': 'Comprehensive/Operational Auditing',
#   'prerequisites_parsed': ['AFM391']},
#  {'course_id': '003279',
#   'subject': 'AFM',
#   'catalog_number': '361',
#   'title': 'Taxation 1',
#   'prerequisites_parsed': ['AFM201']},
#  {'course_id': '013745',
#   'subject': 'AFM',
#   'catalog_number': '362',
#   'title': 'Taxation 1 - Foundations',
#   'prerequisites_parsed': ''},
#  {'course_id': '013913',
#   'subject': 'AFM',
#   'catalog_number': '363',
#   'title': 'Taxation 2 - Integration',
#   'prerequisites_parsed': ['AFM362']},
#  {'course_id': '003258',
#   'subject': 'AFM',
#   'catalog_number': '371',
#   'title': 'Managerial Finance 2',
#   'prerequisites_parsed': ['AFM273']},
#  {'course_id': '011751',
#   'subject': 'AFM',
#   'catalog_number': '372',
#   'title': 'Corporate Finance 2',
#   'prerequisites_parsed': [1, 'AFM272', 'ACTSC291']},
#  {'course_id': '011414',
#   'subject': 'AFM',
#   'catalog_number': '373',
#   'title': 'Cases and Applications in Corporate Finance',
#   'prerequisites_parsed': [1, 'AFM274', [1, 'AFM372', 'ACTSC391']]},
#  {'course_id': '011415',
#   'subject': 'AFM',
#   'catalog_number': '382',
#   'title': 'Performance Measurement and Organization Control',
#   'prerequisites_parsed': ['AFM102']},
#  {'course_id': '003261',
#   'subject': 'AFM',
#   'catalog_number': '391',
#   'title': 'Intermediate Financial Accounting 2',
#   'prerequisites_parsed': ['AFM291']},
#  {'course_id': '003262',
#   'subject': 'AFM',
#   'catalog_number': '401',
#   'title': 'Accounting Theory',
#   'prerequisites_parsed': [1, 'AFM391', 'AFM491']},
#  {'course_id': '013746',
#   'subject': 'AFM',
#   'catalog_number': '411',
#   'title': 'Connections Across Competencies for Accounting Professionals',
#   'prerequisites_parsed': ['AFM311', 'AFM363', 'AFM482', 'AFM491']},
#  {'course_id': '013747',
#   'subject': 'AFM',
#   'catalog_number': '412',
#   'title': 'Connections Across Competencies for Finance Professionals',
#   'prerequisites_parsed': ['AFM311']},
#  {'course_id': '003265',
#   'subject': 'AFM',
#   'catalog_number': '415',
#   'title': 'Special Topics',
#   'prerequisites_parsed': []},
#  {'course_id': '013729',
#   'subject': 'AFM',
#   'catalog_number': '416',
#   'title': 'Special Topics in Finance',
#   'prerequisites_parsed': []},
#  {'course_id': '013728',
#   'subject': 'AFM',
#   'catalog_number': '417',
#   'title': 'Special Topics in Accounting',
#   'prerequisites_parsed': []},
#  {'course_id': '014397',
#   'subject': 'AFM',
#   'catalog_number': '418',
#   'title': 'Special Topics in Finance or Accounting',
#   'prerequisites_parsed': ''},
#  {'course_id': '013732',
#   'subject': 'AFM',
#   'catalog_number': '422',
#   'title': 'Management of Financial Institutions',
#   'prerequisites_parsed': ['AFM322', [1, 'AFM323', 'STAT373']]},
#  {'course_id': '014855',
#   'subject': 'AFM',
#   'catalog_number': '423',
#   'title': 'Topics in Financial Econometrics',
#   'prerequisites_parsed': [1, 'AFM323', 'STAT373']},
#  {'course_id': '003284',
#   'subject': 'AFM',
#   'catalog_number': '424',
#   'title': 'Equity Investments',
#   'prerequisites_parsed': [1,
#    'AFM274',
#    [1, 'AFM372', 'ACTSC391'],
#    'ACTSC372',
#    'ECON371']},
#  {'course_id': '011703',
#   'subject': 'AFM',
#   'catalog_number': '425',
#   'title': 'Fixed Income Securities',
#   'prerequisites_parsed': ['AFM274']},
#  {'course_id': '014475',
#   'subject': 'AFM',
#   'catalog_number': '428',
#   'title': 'Investment Management - Junior Portfolio Manager',
#   'prerequisites_parsed': [1, 'AFM274', [1, 'AFM372', 'ACTSC391']]},
#  {'course_id': '014478',
#   'subject': 'AFM',
#   'catalog_number': '429',
#   'title': 'Investment Management - Senior Portfolio Manager',
#   'prerequisites_parsed': [1, 'AFM274', [1, 'AFM372', 'ACTSC391']]},
#  {'course_id': '003270',
#   'subject': 'AFM',
#   'catalog_number': '431',
#   'title': 'Professional Ethics for Financial Managers',
#   'prerequisites_parsed': ''},
#  {'course_id': '003269',
#   'subject': 'AFM',
#   'catalog_number': '433',
#   'title': 'Business Strategy',
#   'prerequisites_parsed': [[1,
#     [1, 'AFM274', 'AFM371'],
#     [1, 'AFM272', 'ACTSC291']],
#    'AFM291']},
#  {'course_id': '013748',
#   'subject': 'AFM',
#   'catalog_number': '434',
#   'title': 'Governance and Enterprise Risk Management for Global Organizations',
#   'prerequisites_parsed': ['AFM433']},
#  {'course_id': '011178',
#   'subject': 'AFM',
#   'catalog_number': '442',
#   'title': 'E-business: Enterprise Systems',
#   'prerequisites_parsed': [1, 'AFM241', 'CS330', 'CS490']},
#  {'course_id': '011179',
#   'subject': 'AFM',
#   'catalog_number': '443',
#   'title': 'E-business: Introduction to Electronic Commerce',
#   'prerequisites_parsed': [1, 'AFM241', 'CS330', 'CS490']},
#  {'course_id': '003275',
#   'subject': 'AFM',
#   'catalog_number': '451',
#   'title': 'Audit Strategy',
#   'prerequisites_parsed': ['AFM391']},
#  {'course_id': '003278',
#   'subject': 'AFM',
#   'catalog_number': '452',
#   'title': 'Comprehensive/Operational Auditing',
#   'prerequisites_parsed': ['AFM391']},
#  {'course_id': '003280',
#   'subject': 'AFM',
#   'catalog_number': '461',
#   'title': 'Taxation 2',
#   'prerequisites_parsed': ['AFM361']},
#  {'course_id': '013914',
#   'subject': 'AFM',
#   'catalog_number': '462',
#   'title': 'Taxation 3 - Tax Planning Topics',
#   'prerequisites_parsed': ['AFM363']},
#  {'course_id': '011414',
#   'subject': 'AFM',
#   'catalog_number': '471',
#   'title': 'Cases and Applications in Corporate Finance',
#   'prerequisites_parsed': [1,
#    [1, 'AFM274', 'AFM371'],
#    [1, 'AFM372', 'ACTSC391']]},
#  {'course_id': '003284',
#   'subject': 'AFM',
#   'catalog_number': '472',
#   'title': 'Equity Investments',
#   'prerequisites_parsed': [1,
#    [1, 'AFM274', 'AFM371'],
#    'ACTSC372',
#    [1, 'ACTSC391', 'AFM372'],
#    'ECON372']},
#  {'course_id': '011701',
#   'subject': 'AFM',
#   'catalog_number': '473',
#   'title': 'Advanced Topics in Corporate Finance',
#   'prerequisites_parsed': [1,
#    [1, 'AFM274', 'AFM371'],
#    [1, 'AFM372', 'ACTSC391']]},
#  {'course_id': '011702',
#   'subject': 'AFM',
#   'catalog_number': '474',
#   'title': 'Derivative Securities',
#   'prerequisites_parsed': [1,
#    [1, 'AFM274', 'AFM371'],
#    [1, 'AFM372', 'ACTSC391']]},
#  {'course_id': '011703',
#   'subject': 'AFM',
#   'catalog_number': '475',
#   'title': 'Fixed Income Securities',
#   'prerequisites_parsed': [1,
#    [1, 'AFM274', 'AFM371'],
#    [1, 'AFM372', 'ACTSC391']]},
#  {'course_id': '011760',
#   'subject': 'AFM',
#   'catalog_number': '476',
#   'title': 'Advanced Corporate Finance',
#   'prerequisites_parsed': [1, [1, 'AFM372', 'ACTSC391'], 'ACTSC372']},
#  {'course_id': '013730',
#   'subject': 'AFM',
#   'catalog_number': '477',
#   'title': 'Mergers and Acquisitions',
#   'prerequisites_parsed': [1,
#    [1, 'AFM274', 'AFM371'],
#    [1, 'AFM372', 'ACTSC391']]},
#  {'course_id': '013749',
#   'subject': 'AFM',
#   'catalog_number': '478',
#   'title': 'International Financial Management',
#   'prerequisites_parsed': [1,
#    [1, 'AFM274', 'AFM371'],
#    [1, 'AFM372', 'ACTSC391']]},
#  {'course_id': '003260',
#   'subject': 'AFM',
#   'catalog_number': '481',
#   'title': 'Cost Management Systems',
#   'prerequisites_parsed': ['AFM102']},
#  {'course_id': '011415',
#   'subject': 'AFM',
#   'catalog_number': '482',
#   'title': 'Performance Measurement and Organization Control',
#   'prerequisites_parsed': ['AFM433', 'AFM481']},
#  {'course_id': '014229',
#   'subject': 'AFM',
#   'catalog_number': '483',
#   'title': 'Applications of Analytics to Business',
#   'prerequisites_parsed': [1,
#    'ECON221',
#    'STAT211',
#    'STAT230',
#    'STAT231',
#    'STAT240',
#    'STAT241']},
#  {'course_id': '014230',
#   'subject': 'AFM',
#   'catalog_number': '484',
#   'title': 'Advanced Management Control Systems',
#   'prerequisites_parsed': [1, 'AFM382', 'AFM482']},
#  {'course_id': '003285',
#   'subject': 'AFM',
#   'catalog_number': '491',
#   'title': 'Advanced Financial Accounting',
#   'prerequisites_parsed': ['AFM391']},
#  {'course_id': '011704',
#   'subject': 'AFM',
#   'catalog_number': '492',
#   'title': 'Financial Statement Analysis',
#   'prerequisites_parsed': ['AFM291',
#    'AFM391',
#    [1, [1, 'AFM274', 'AFM371'], [1, 'AFM372', 'ACTSC391']]]},
#  {'course_id': '003286',
#   'subject': 'AFM',
#   'catalog_number': '501',
#   'title': 'Contemporary Issues in Assurance and Accounting',
#   'prerequisites_parsed': ''},
#  {'course_id': '003287',
#   'subject': 'AFM',
#   'catalog_number': '502',
#   'title': 'Control Systems in a Computer Environment',
#   'prerequisites_parsed': ''},
#  {'course_id': '003288',
#   'subject': 'AFM',
#   'catalog_number': '503',
#   'title': 'Issues and Problems in Accounting Practice',
#   'prerequisites_parsed': ''},
#  {'course_id': '003289',
#   'subject': 'AFM',
#   'catalog_number': '504',
#   'title': 'Issues and Problems in External Reporting',
#   'prerequisites_parsed': ''},
#  {'course_id': '013580',
#   'subject': 'AHS',
#   'catalog_number': '150',
#   'title': 'Foundations of Human Anatomy and Physiology',
#   'prerequisites_parsed': ''},
#  {'course_id': '003320',
#   'subject': 'AMATH',
#   'catalog_number': '261',
#   'title': 'Classical Mechanics and Special Relativity',
#   'prerequisites_parsed': [[1, 'AMATH250', 'MATH228'], 'PHYS122']},
#  {'course_id': '013715',
#   'subject': 'AHS',
#   'catalog_number': '782',
#   'title': 'Selected Topics in Applied Health Sciences',
#   'prerequisites_parsed': []},
#  {'course_id': '003316',
#   'subject': 'AMATH',
#   'catalog_number': '231',
#   'title': 'Calculus 4',
#   'prerequisites_parsed': [1, 'MATH237', 'MATH247']},
#  {'course_id': '011363',
#   'subject': 'AMATH',
#   'catalog_number': '242',
#   'title': 'Introduction to Computational Mathematics',
#   'prerequisites_parsed': [[1, 'CS116', 'CS136', 'CS138', 'CS146'],
#    [1, 'MATH235', 'MATH245'],
#    [1, 'MATH237', 'MATH247']]},
#  {'course_id': '003317',
#   'subject': 'AMATH',
#   'catalog_number': '250',
#   'title': 'Introduction to Differential Equations',
#   'prerequisites_parsed': [[1,
#     'MATH106',
#     'MATH114',
#     'MATH115',
#     'MATH136',
#     'MATH146',
#     'NE112'],
#    [1, 'MATH128', 'MATH138', 'MATH148']]},
#  {'course_id': '014120',
#   'subject': 'AMATH',
#   'catalog_number': '251',
#   'title': 'Introduction to Differential Equations (Advanced level)',
#   'prerequisites_parsed': [[1,
#     'MATH106',
#     'MATH114',
#     'MATH115',
#     'MATH136',
#     'MATH146',
#     'NE112'],
#    [1, 'MATH128', 'MATH138', 'MATH148']]},
#  {'course_id': '013864',
#   'subject': 'AMATH',
#   'catalog_number': '271',
#   'title': 'Introduction to Theoretical Mechanics',
#   'prerequisites_parsed': ['MATH138', 'PHYS121']},
#  {'course_id': '013317',
#   'subject': 'AMATH',
#   'catalog_number': '310',
#   'title': 'Environmental Informatics',
#   'prerequisites_parsed': [[1, 'PHYS112', 'PHYS122', 'PHYS125'],
#    [1, 'MATH118', 'MATH119', 'MATH128', 'MATH138', 'MATH148'],
#    [1,
#     'AMATH250',
#     'AMATH251',
#     'AMATH350',
#     'CIVE222',
#     'ENVE223',
#     'MATH218',
#     'MATH228',
#     'ME203',
#     'SYDE211']]},
#  {'course_id': '003323',
#   'subject': 'AMATH',
#   'catalog_number': '331',
#   'title': 'Applied Real Analysis',
#   'prerequisites_parsed': [1, 'MATH237', 'MATH247']},
#  {'course_id': '003324',
#   'subject': 'AMATH',
#   'catalog_number': '332',
#   'title': 'Applied Complex Analysis',
#   'prerequisites_parsed': [1, 'MATH237', 'MATH247']},
#  {'course_id': '011451',
#   'subject': 'AMATH',
#   'catalog_number': '342',
#   'title': 'Computational Methods for Differential Equations',
#   'prerequisites_parsed': [[1, 'AMATH242', 'CS371'],
#    [1, 'AMATH250', 'AMATH251', 'AMATH350', 'MATH218', 'MATH228']]},
#  {'course_id': '003328',
#   'subject': 'AMATH',
#   'catalog_number': '343',
#   'title': 'Discrete Models in Applied Mathematics',
#   'prerequisites_parsed': [1, 'MATH128', 'MATH138', 'MATH148']},
#  {'course_id': '012744',
#   'subject': 'AMATH',
#   'catalog_number': '350',
#   'title': 'Differential Equations for Business and Economics',
#   'prerequisites_parsed': [[1, 'MATH136', 'MATH146'],
#    [1, 'MATH237', 'MATH247'],
#    [1, 'STAT230'],
#    [1, [1, 'AFM272', 'ACTSC291'], 'ACTSC371', 'ECON371', 'BUS393W']]},
#  {'course_id': '003329',
#   'subject': 'AMATH',
#   'catalog_number': '351',
#   'title': 'Ordinary Differential Equations 2',
#   'prerequisites_parsed': [[1, 'AMATH250', 'AMATH251'],
#    [1, 'MATH237', 'MATH247']]},
#  {'course_id': '003330',
#   'subject': 'AMATH',
#   'catalog_number': '353',
#   'title': 'Partial Differential Equations 1',
#   'prerequisites_parsed': ['AMATH231',
#    [1,
#     'AMATH250',
#     'AMATH251',
#     [1, 'MATH211', 'ECE205'],
#     'MATH218',
#     'MATH228']]},
#  {'course_id': '003331',
#   'subject': 'AMATH',
#   'catalog_number': '361',
#   'title': 'Continuum Mechanics',
#   'prerequisites_parsed': ['AMATH231', [1, 'AMATH271', 'PHYS263']]},
#  {'course_id': '003338',
#   'subject': 'AMATH',
#   'catalog_number': '373',
#   'title': 'Quantum Theory 1',
#   'prerequisites_parsed': ['AMATH231', [1, 'AMATH271', 'PHYS263'], 'PHYS234']},
#  {'course_id': '011910',
#   'subject': 'AMATH',
#   'catalog_number': '382',
#   'title': 'Computational Modelling of Cellular Systems',
#   'prerequisites_parsed': [1,
#    'MATH118',
#    'MATH119',
#    'MATH128',
#    'MATH138',
#    'MATH148']},
#  {'course_id': '012282',
#   'subject': 'AMATH',
#   'catalog_number': '391',
#   'title': 'From Fourier to Wavelets',
#   'prerequisites_parsed': [[1, 'AMATH231', 'ECE342', 'PHYS364', 'SYDE252'],
#    [1, 'MATH114', 'MATH115', 'MATH136', 'MATH146', 'SYDE114']]},
#  {'course_id': '011448',
#   'subject': 'AMATH',
#   'catalog_number': '442',
#   'title': 'Computational Methods for Partial Differential Equations',
#   'prerequisites_parsed': ['AMATH342']},
#  {'course_id': '011443',
#   'subject': 'AMATH',
#   'catalog_number': '444',
#   'title': 'Applications of Computational Differential Equations',
#   'prerequisites_parsed': [1, 'AMATH342', 'CM352']},
#  {'course_id': '003354',
#   'subject': 'AMATH',
#   'catalog_number': '451',
#   'title': 'Introduction to Dynamical Systems',
#   'prerequisites_parsed': ['AMATH351']},
#  {'course_id': '003355',
#   'subject': 'AMATH',
#   'catalog_number': '453',
#   'title': 'Partial Differential Equations 2',
#   'prerequisites_parsed': ['AMATH351', 'AMATH353']},
#  {'course_id': '003356',
#   'subject': 'AMATH',
#   'catalog_number': '455',
#   'title': 'Control Theory',
#   'prerequisites_parsed': [[1, [1, 'AMATH332', 'PMATH332'], 'PMATH352'],
#    'AMATH351']},
#  {'course_id': '003357',
#   'subject': 'AMATH',
#   'catalog_number': '456',
#   'title': 'Calculus of Variations',
#   'prerequisites_parsed': [[1, 'MATH237', 'MATH247'],
#    [1,
#     'AMATH250',
#     'AMATH251',
#     [1, 'MATH211', 'ECE205'],
#     'MATH218',
#     'MATH228']]},
#  {'course_id': '003359',
#   'subject': 'AMATH',
#   'catalog_number': '463',
#   'title': 'Fluid Mechanics',
#   'prerequisites_parsed': [[1, 'AMATH353', 'PHYS364'], 'AMATH361']},
#  {'course_id': '003369',
#   'subject': 'AMATH',
#   'catalog_number': '473',
#   'title': 'Quantum Theory 2',
#   'prerequisites_parsed': [1, 'AMATH373', 'PHYS334']},
#  {'course_id': '003371',
#   'subject': 'AMATH',
#   'catalog_number': '475',
#   'title': 'Introduction to General Relativity',
#   'prerequisites_parsed': [[1, 'AMATH231', 'MATH227'],
#    [1, 'AMATH271', 'PHYS263']]},
#  {'course_id': '003382',
#   'subject': 'AMATH',
#   'catalog_number': '495',
#   'title': 'Reading Course',
#   'prerequisites_parsed': ''},
#  {'course_id': '011278',
#   'subject': 'AMATH',
#   'catalog_number': '655',
#   'title': 'Control Theory',
#   'prerequisites_parsed': []},
#  {'course_id': '011279',
#   'subject': 'AMATH',
#   'catalog_number': '663',
#   'title': 'Fluid Mechanics',
#   'prerequisites_parsed': []},
#  {'course_id': '011280',
#   'subject': 'AMATH',
#   'catalog_number': '673',
#   'title': 'Quantum Mechanics',
#   'prerequisites_parsed': []},
#  {'course_id': '011281',
#   'subject': 'AMATH',
#   'catalog_number': '675',
#   'title': 'General Relativity',
#   'prerequisites_parsed': []},
#  {'course_id': '000116',
#   'subject': 'AMATH',
#   'catalog_number': '731',
#   'title': 'Applied Functional Analysis',
#   'prerequisites_parsed': []},
#  {'course_id': '011283',
#   'subject': 'AMATH',
#   'catalog_number': '732',
#   'title': 'Asymptotic Analysis and Perturbation Theory',
#   'prerequisites_parsed': []},
#  {'course_id': '012670',
#   'subject': 'AMATH',
#   'catalog_number': '740',
#   'title': 'Numerical Analysis',
#   'prerequisites_parsed': []},
#  {'course_id': '000724',
#   'subject': 'AMATH',
#   'catalog_number': '741',
#   'title': 'Numerical Solution of Partial Differential Equations',
#   'prerequisites_parsed': []},
#  {'course_id': '000118',
#   'subject': 'AMATH',
#   'catalog_number': '751',
#   'title': 'Advanced Ordinary Differential Equations',
#   'prerequisites_parsed': []},
#  {'course_id': '000119',
#   'subject': 'AMATH',
#   'catalog_number': '753',
#   'title': 'Advanced Partial Differential Equations',
#   'prerequisites_parsed': []},
#  {'course_id': '011284',
#   'subject': 'AMATH',
#   'catalog_number': '777',
#   'title': 'Stochastic Processes in the Physical Sciences',
#   'prerequisites_parsed': []},
#  {'course_id': '011285',
#   'subject': 'AMATH',
#   'catalog_number': '851',
#   'title': 'Stability Theory and Applications',
#   'prerequisites_parsed': []},
#  {'course_id': '000132',
#   'subject': 'AMATH',
#   'catalog_number': '855',
#   'title': 'Advanced Systems Analysis and Control',
#   'prerequisites_parsed': []},
#  {'course_id': '000133',
#   'subject': 'AMATH',
#   'catalog_number': '863',
#   'title': 'Hydrodynamic Stability and Turbulence',
#   'prerequisites_parsed': []},
#  {'course_id': '000134',
#   'subject': 'AMATH',
#   'catalog_number': '867',
#   'title': 'Dispersive and Nonlinear Waves',
#   'prerequisites_parsed': []},
#  {'course_id': '011589',
#   'subject': 'AMATH',
#   'catalog_number': '871',
#   'title': 'Quantum Information Processing',
#   'prerequisites_parsed': []},
#  {'course_id': '012151',
#   'subject': 'AMATH',
#   'catalog_number': '872',
#   'title': 'Introduction to Quantum Field Theory for Cosmology',
#   'prerequisites_parsed': [1, 'AMATH673', 'PHYS701']},
#  {'course_id': '000135',
#   'subject': 'AMATH',
#   'catalog_number': '873',
#   'title': 'Introduction to Quantum Field Theory',
#   'prerequisites_parsed': [1, 'AMATH673', 'PHYS701']},
#  {'course_id': '010439',
#   'subject': 'AMATH',
#   'catalog_number': '874',
#   'title': 'Advanced techniques in General Relativity and Applications to Black Holes',
#   'prerequisites_parsed': []},
#  {'course_id': '011282',
#   'subject': 'AMATH',
#   'catalog_number': '875',
#   'title': 'Introduction to General Relativity with Applications to Cosmology',
#   'prerequisites_parsed': []},
#  {'course_id': '012567',
#   'subject': 'AMATH',
#   'catalog_number': '876',
#   'title': 'Open Quantum Systems',
#   'prerequisites_parsed': [1, 'AMATH473', 'AMATH673']},
#  {'course_id': '013468',
#   'subject': 'AMATH',
#   'catalog_number': '881',
#   'title': 'Introduction to Mathematical Oncology',
#   'prerequisites_parsed': []},
#  {'course_id': '013469',
#   'subject': 'AMATH',
#   'catalog_number': '882',
#   'title': 'Mathematical Cell Biology',
#   'prerequisites_parsed': []},
#  {'course_id': '011357',
#   'subject': 'AMATH',
#   'catalog_number': '900',
#   'title': 'Topics in Applied Mathematics',
#   'prerequisites_parsed': []},
#  {'course_id': '011692',
#   'subject': 'BET',
#   'catalog_number': '606',
#   'title': 'Entrepreneurial Applications of Digital Media',
#   'prerequisites_parsed': ''},
#  {'course_id': '003389',
#   'subject': 'ANTH',
#   'catalog_number': '101',
#   'title': 'Human and Cultural Evolution',
#   'prerequisites_parsed': []},
#  {'course_id': '003391',
#   'subject': 'ANTH',
#   'catalog_number': '102',
#   'title': 'Introduction to Social and Cultural Anthropology',
#   'prerequisites_parsed': []},
#  {'course_id': '003396',
#   'subject': 'ANTH',
#   'catalog_number': '201',
#   'title': 'Introduction to Archaeology',
#   'prerequisites_parsed': []},
#  {'course_id': '003399',
#   'subject': 'ANTH',
#   'catalog_number': '202',
#   'title': 'Social and Cultural Anthropology',
#   'prerequisites_parsed': ['ANTH102']},
#  {'course_id': '003422',
#   'subject': 'ANTH',
#   'catalog_number': '233',
#   'title': 'Inuit Cultures',
#   'prerequisites_parsed': ''},
#  {'course_id': '003426',
#   'subject': 'ANTH',
#   'catalog_number': '260',
#   'title': 'Human Evolution',
#   'prerequisites_parsed': ['ANTH101']},
#  {'course_id': '003427',
#   'subject': 'ANTH',
#   'catalog_number': '261',
#   'title': 'Primate Behaviour',
#   'prerequisites_parsed': []},
#  {'course_id': '003432',
#   'subject': 'ANTH',
#   'catalog_number': '290',
#   'title': 'Visual Anthropology',
#   'prerequisites_parsed': []},
#  {'course_id': '003433',
#   'subject': 'ANTH',
#   'catalog_number': '300',
#   'title': 'Practicing Anthropology',
#   'prerequisites_parsed': ['ANTH202']},
#  {'course_id': '013559',
#   'subject': 'ANTH',
#   'catalog_number': '302',
#   'title': 'Anthropology of Violence: Political Conflict and Change',
#   'prerequisites_parsed': ['ANTH202']},
#  {'course_id': '013560',
#   'subject': 'ANTH',
#   'catalog_number': '303',
#   'title': 'Anthropology of Digital Media',
#   'prerequisites_parsed': ['ANTH202']},
#  {'course_id': '014127',
#   'subject': 'ANTH',
#   'catalog_number': '305',
#   'title': 'Paleopathology of Health and Disease',
#   'prerequisites_parsed': [1, 'ANTH204', 'ANTH260', 'ANTH201']},
#  {'course_id': '003445',
#   'subject': 'ANTH',
#   'catalog_number': '320',
#   'title': 'Hunter-Gatherer Archaeology',
#   'prerequisites_parsed': [1, 'ANTH201', 'CLAS221']},
#  {'course_id': '003446',
#   'subject': 'ANTH',
#   'catalog_number': '321',
#   'title': 'Archaeology of Complex Cultures',
#   'prerequisites_parsed': [1, 'ANTH201', 'CLAS221']},
#  {'course_id': '003448',
#   'subject': 'ANTH',
#   'catalog_number': '322',
#   'title': 'The Archaeology of the Great Lakes Area',
#   'prerequisites_parsed': [1, 'ANTH201', 'CLAS221']},
#  {'course_id': '003452',
#   'subject': 'ANTH',
#   'catalog_number': '330',
#   'title': 'Environmental Anthropology',
#   'prerequisites_parsed': ['ANTH202']},
#  {'course_id': '003460',
#   'subject': 'ANTH',
#   'catalog_number': '345',
#   'title': 'Directed Research in Anthropology',
#   'prerequisites_parsed': ''},
#  {'course_id': '011871',
#   'subject': 'ANTH',
#   'catalog_number': '347',
#   'title': 'Medical Anthropology',
#   'prerequisites_parsed': ['ANTH202']},
#  {'course_id': '013324',
#   'subject': 'ANTH',
#   'catalog_number': '348',
#   'title': 'Anthropology of Tourism',
#   'prerequisites_parsed': ['ANTH102']},
#  {'course_id': '003462',
#   'subject': 'ANTH',
#   'catalog_number': '351',
#   'title': 'Indigenous Practices & Relations: A Comparative Approach',
#   'prerequisites_parsed': [1, 'ANTH102', 'ANTH230', 'ANTH370']},
#  {'course_id': '003463',
#   'subject': 'ANTH',
#   'catalog_number': '352',
#   'title': 'Anthropological Thought',
#   'prerequisites_parsed': ['ANTH202']},
#  {'course_id': '009886',
#   'subject': 'ANTH',
#   'catalog_number': '355',
#   'title': 'Human Osteology',
#   'prerequisites_parsed': [1, 'ANTH204', 'ANTH260', 'ANTH201']},
#  {'course_id': '014128',
#   'subject': 'ANTH',
#   'catalog_number': '361',
#   'title': 'Biocultural Examination of Primate Conservation',
#   'prerequisites_parsed': ['ANTH202', 'ANTH261']},
#  {'course_id': '003466',
#   'subject': 'ANTH',
#   'catalog_number': '365',
#   'title': 'Human Evolution',
#   'prerequisites_parsed': [1, 'ANTH204', 'ANTH260', 'ANTH201']},
#  {'course_id': '003945',
#   'subject': 'ANTH',
#   'catalog_number': '370',
#   'title': 'Issues in Contemporary Native Communities in Canada',
#   'prerequisites_parsed': []},
#  {'course_id': '012624',
#   'subject': 'ANTH',
#   'catalog_number': '371',
#   'title': 'Anthropological Field Experience',
#   'prerequisites_parsed': [1, 'ANTH101', 'ANTH102']},
#  {'course_id': '003471',
#   'subject': 'ANTH',
#   'catalog_number': '390A',
#   'title': 'Reading in Anthropology',
#   'prerequisites_parsed': ''},
#  {'course_id': '003472',
#   'subject': 'ANTH',
#   'catalog_number': '390B',
#   'title': 'Reading in Anthropology',
#   'prerequisites_parsed': ''},
#  {'course_id': '003473',
#   'subject': 'ANTH',
#   'catalog_number': '391',
#   'title': 'Reading in Anthropology',
#   'prerequisites_parsed': ''},
#  {'course_id': '003474',
#   'subject': 'ANTH',
#   'catalog_number': '393',
#   'title': 'Reading in Anthropology',
#   'prerequisites_parsed': ''},
#  {'course_id': '012749',
#   'subject': 'ANTH',
#   'catalog_number': '395',
#   'title': 'Anthropological Study Abroad',
#   'prerequisites_parsed': ''},
#  {'course_id': '003475',
#   'subject': 'ANTH',
#   'catalog_number': '400',
#   'title': 'Special Topics in Anthropology',
#   'prerequisites_parsed': []},
#  {'course_id': '013561',
#   'subject': 'ANTH',
#   'catalog_number': '402',
#   'title': 'Palestine/Israel: Anthropological Perspectives',
#   'prerequisites_parsed': ['ANTH202']},
#  {'course_id': '013991',
#   'subject': 'ANTH',
#   'catalog_number': '403',
#   'title': 'Anthropological Inquiry into the Origin of Language and Cultural Behaviour',
#   'prerequisites_parsed': ['ANTH202', [1, 'ANTH204', 'ANTH260', 'ANTH201']]},
#  {'course_id': '009885',
#   'subject': 'ANTH',
#   'catalog_number': '440',
#   'title': 'Archaeological Analysis and Interpretation',
#   'prerequisites_parsed': [1, 'ANTH201', 'CLAS221']},
#  {'course_id': '011982',
#   'subject': 'ANTH',
#   'catalog_number': '455',
#   'title': 'Skeletal Biology and Forensics',
#   'prerequisites_parsed': ['ANTH355']},
#  {'course_id': '003482',
#   'subject': 'ANTH',
#   'catalog_number': '460',
#   'title': 'Human Adaptation and Variation',
#   'prerequisites_parsed': ['ANTH260']},
#  {'course_id': '009887',
#   'subject': 'ANTH',
#   'catalog_number': '470',
#   'title': 'Archaeological Field Methods',
#   'prerequisites_parsed': []},
#  {'course_id': '003485',
#   'subject': 'ANTH',
#   'catalog_number': '492A',
#   'title': 'Reading in Anthropology',
#   'prerequisites_parsed': ''},
#  {'course_id': '003486',
#   'subject': 'ANTH',
#   'catalog_number': '492B',
#   'title': 'Reading in Anthropology',
#   'prerequisites_parsed': ''},
#  {'course_id': '003487',
#   'subject': 'ANTH',
#   'catalog_number': '495',
#   'title': 'Reading in Anthropology',
#   'prerequisites_parsed': ''},
#  {'course_id': '003488',
#   'subject': 'ANTH',
#   'catalog_number': '497',
#   'title': 'Reading in Anthropology',
#   'prerequisites_parsed': ''},
#  {'course_id': '003489',
#   'subject': 'ANTH',
#   'catalog_number': '499A',
#   'title': 'Honours Essay',
#   'prerequisites_parsed': ''},
#  {'course_id': '003490',
#   'subject': 'ANTH',
#   'catalog_number': '499B',
#   'title': 'Honours Essay',
#   'prerequisites_parsed': ''},
#  {'course_id': '012727',
#   'subject': 'ANTH',
#   'catalog_number': '600',
#   'title': 'Public Issues Anthropology',
#   'prerequisites_parsed': []},
#  {'course_id': '012968',
#   'subject': 'ANTH',
#   'catalog_number': '604',
#   'title': 'Human Development in a Cross-Cultural Perspective',
#   'prerequisites_parsed': []},
#  {'course_id': '012732',
#   'subject': 'ANTH',
#   'catalog_number': '605',
#   'title': 'Selected Topics in Theory and Research',
#   'prerequisites_parsed': []},
#  {'course_id': '012729',
#   'subject': 'ANTH',
#   'catalog_number': '608',
#   'title': 'Anthropological Theory',
#   'prerequisites_parsed': []},
#  {'course_id': '012728',
#   'subject': 'ANTH',
#   'catalog_number': '614',
#   'title': 'Research Methods',
#   'prerequisites_parsed': []},
#  {'course_id': '012730',
#   'subject': 'ANTH',
#   'catalog_number': '655',
#   'title': 'Skeletal Biology and Forensics',
#   'prerequisites_parsed': []},
#  {'course_id': '013815',
#   'subject': 'ANTH',
#   'catalog_number': '659',
#   'title': 'Conservation, Communities and Globalization',
#   'prerequisites_parsed': []},
#  {'course_id': '012737',
#   'subject': 'ANTH',
#   'catalog_number': '660',
#   'title': 'Reading Course',
#   'prerequisites_parsed': []},
#  {'course_id': '013807',
#   'subject': 'ANTH',
#   'catalog_number': '661',
#   'title': 'Research Seminar in Public Issues Anthropology',
#   'prerequisites_parsed': []},
#  {'course_id': '012731',
#   'subject': 'ANTH',
#   'catalog_number': '662',
#   'title': 'Human Adaptation and Evolution',
#   'prerequisites_parsed': []},
#  {'course_id': '012198',
#   'subject': 'APPLS',
#   'catalog_number': '205R',
#   'title': 'Second Language Acquisition',
#   'prerequisites_parsed': ''},
#  {'course_id': '012718',
#   'subject': 'APPLS',
#   'catalog_number': '301',
#   'title': 'Language, Culture, and Identity',
#   'prerequisites_parsed': ''},
#  {'course_id': '011980',
#   'subject': 'APPLS',
#   'catalog_number': '304R',
#   'title': 'Second Language Teaching Methodology',
#   'prerequisites_parsed': ''},
#  {'course_id': '012356',
#   'subject': 'APPLS',
#   'catalog_number': '306R',
#   'title': 'Second Language Assessment and Testing',
#   'prerequisites_parsed': [1,
#    'APPLS205R',
#    'APPLS304R',
#    [1, 'APPLS301', 'GER301']]},
#  {'course_id': '013720',
#   'subject': 'ARBUS',
#   'catalog_number': '100',
#   'title': 'Introduction to Arts and Business',
#   'prerequisites_parsed': ''},
#  {'course_id': '003243',
#   'subject': 'ARBUS',
#   'catalog_number': '101',
#   'title': 'Introduction to Business in North America',
#   'prerequisites_parsed': ''},
#  {'course_id': '003239',
#   'subject': 'ARBUS',
#   'catalog_number': '102',
#   'title': 'Accounting Information for Managers',
#   'prerequisites_parsed': ''},
#  {'course_id': '014241',
#   'subject': 'ARBUS',
#   'catalog_number': '200',
#   'title': 'Entrepreneurship Principles and Practices',
# ...
#   'subject': 'CLAS',
#   'catalog_number': '321',
#   'title': 'Archaeology of Complex Cultures',
#   'prerequisites_parsed': [1, 'ANTH201', 'CLAS221']},
#  {'course_id': '004290',
#   'subject': 'CLAS',
#   'catalog_number': '325',
#   'title': 'Greek and Roman Religion',
#   'prerequisites_parsed': [1, 'CLAS100', 'CLAS104', 'CLAS201', 'CLAS202']},
#  {'course_id': '011787',
#   'subject': 'CLAS',
#   'catalog_number': '327',
#   'title': 'Astrology and Magic',
#   'prerequisites_parsed': [1, 'CLAS100', 'CLAS104', 'CLAS201', 'CLAS202']},
#  {'course_id': '012911',
#   'subject': 'CLAS',
#   'catalog_number': '331',
#   'title': 'Advanced Studies in Ancient Literature',
#   'prerequisites_parsed': [1, 'CLAS231', 'CLAS232']},
#  {'course_id': '012914',
#   'subject': 'CLAS',
#   'catalog_number': '341',
#   'title': 'Advanced Studies in Greek Art and Architecture',
#   'prerequisites_parsed': [1, 'CLAS241', 'FINE241']},
#  {'course_id': '012915',
#   'subject': 'CLAS',
#   'catalog_number': '342',
#   'title': 'Advanced Studies in Roman Art and Architecture',
#   'prerequisites_parsed': [1, 'CLAS242', 'FINE242']},
#  {'course_id': '012912',
#   'subject': 'CLAS',
#   'catalog_number': '351',
#   'title': 'Advanced Studies in Greek History',
#   'prerequisites_parsed': [1, 'CLAS251', 'HIST242']},
#  {'course_id': '012913',
#   'subject': 'CLAS',
#   'catalog_number': '352',
#   'title': 'Advanced Studies in Roman History',
#   'prerequisites_parsed': [1, 'CLAS252', 'HIST252']},
#  {'course_id': '007324',
#   'subject': 'CLAS',
#   'catalog_number': '361',
#   'title': 'History of Ancient Philosophy',
#   'prerequisites_parsed': None},
#  {'course_id': '007325',
#   'subject': 'CLAS',
#   'catalog_number': '362',
#   'title': 'History of Ancient Philosophy 2',
#   'prerequisites_parsed': []},
#  {'course_id': '004300',
#   'subject': 'CLAS',
#   'catalog_number': '384',
#   'title': 'Science and Technology of Ancient Greece and Rome',
#   'prerequisites_parsed': [1, 'CLAS201', 'CLAS202', 'CLAS251', 'CLAS252']},
#  {'course_id': '004301',
#   'subject': 'CLAS',
#   'catalog_number': '390',
#   'title': 'Classical Studies Abroad',
#   'prerequisites_parsed': ''},
#  {'course_id': '013557',
#   'subject': 'CLAS',
#   'catalog_number': '395',
#   'title': 'Research Skills Training',
#   'prerequisites_parsed': []},
#  {'course_id': '011189',
#   'subject': 'CLAS',
#   'catalog_number': '461',
#   'title': 'Studies in Ancient Philosophy',
#   'prerequisites_parsed': ''},
#  {'course_id': '004303',
#   'subject': 'CLAS',
#   'catalog_number': '485',
#   'title': 'Greco-Roman Civilization and History',
#   'prerequisites_parsed': ''},
#  {'course_id': '009523',
#   'subject': 'CLAS',
#   'catalog_number': '486',
#   'title': 'Senior Seminar',
#   'prerequisites_parsed': ['CLAS251',
#    'CLAS252',
#    [1, 'CLAS231', 'CLAS232'],
#    [1, 'CLAS241', 'CLAS242']]},
#  {'course_id': '004315',
#   'subject': 'CLAS',
#   'catalog_number': '490A',
#   'title': 'Senior Honours Thesis',
#   'prerequisites_parsed': []},
#  {'course_id': '004316',
#   'subject': 'CLAS',
#   'catalog_number': '490B',
#   'title': 'Senior Honours Thesis',
#   'prerequisites_parsed': []},
#  {'course_id': '004317',
#   'subject': 'CLAS',
#   'catalog_number': '492',
#   'title': 'Directed Study',
#   'prerequisites_parsed': []},
#  {'course_id': '013021',
#   'subject': 'CLAS',
#   'catalog_number': '600',
#   'title': 'Research Methods in Classical Studies',
#   'prerequisites_parsed': []},
#  {'course_id': '013033',
#   'subject': 'CLAS',
#   'catalog_number': '601',
#   'title': 'The Integration of the Ancient Mediterranean World',
#   'prerequisites_parsed': []},
#  {'course_id': '014416',
#   'subject': 'CLAS',
#   'catalog_number': '631',
#   'title': 'Studies in Greek Literature',
#   'prerequisites_parsed': []},
#  {'course_id': '013758',
#   'subject': 'CLAS',
#   'catalog_number': '632',
#   'title': 'Studies in Latin Literature',
#   'prerequisites_parsed': []},
#  {'course_id': '013022',
#   'subject': 'CLAS',
#   'catalog_number': '633',
#   'title': 'Studies in Ancient Literature',
#   'prerequisites_parsed': []},
#  {'course_id': '013037',
#   'subject': 'CLAS',
#   'catalog_number': '641',
#   'title': 'Studies in Greek Art and Architecture',
#   'prerequisites_parsed': []},
#  {'course_id': '014417',
#   'subject': 'CLAS',
#   'catalog_number': '642',
#   'title': 'Studies in Roman Art in Architecture',
#   'prerequisites_parsed': []},
#  {'course_id': '013024',
#   'subject': 'CLAS',
#   'catalog_number': '643',
#   'title': 'Studies in Ancient Art and Architecture',
#   'prerequisites_parsed': []},
#  {'course_id': '014418',
#   'subject': 'CLAS',
#   'catalog_number': '651',
#   'title': 'Topics in Greek History',
#   'prerequisites_parsed': []},
#  {'course_id': '014419',
#   'subject': 'CLAS',
#   'catalog_number': '652',
#   'title': 'Topics in Roman History',
#   'prerequisites_parsed': []},
#  {'course_id': '013025',
#   'subject': 'CLAS',
#   'catalog_number': '653',
#   'title': 'Topics in Ancient History',
#   'prerequisites_parsed': []},
#  {'course_id': '014420',
#   'subject': 'CLAS',
#   'catalog_number': '695',
#   'title': 'Classical Studies Abroad',
#   'prerequisites_parsed': []},
#  {'course_id': '011431',
#   'subject': 'CM',
#   'catalog_number': '361',
#   'title': 'Computational Statistics and Data Analysis',
#   'prerequisites_parsed': [[1, 'MATH237', 'MATH247'],
#    [1, 'STAT230', 'STAT240'],
#    [1, 'STAT231', 'STAT241']]},
#  {'course_id': '011444',
#   'subject': 'CM',
#   'catalog_number': '375',
#   'title': 'Computational Linear Algebra',
#   'prerequisites_parsed': [1,
#    [1, 'AMATH242', 'AMATH341', 'CM271', 'CS371'],
#    'CS370']},
#  {'course_id': '012670',
#   'subject': 'CM',
#   'catalog_number': '670',
#   'title': 'Numerical Analysis',
#   'prerequisites_parsed': []},
#  {'course_id': '000626',
#   'subject': 'CM',
#   'catalog_number': '730',
#   'title': 'Introduction to Symbolic Computation',
#   'prerequisites_parsed': []},
#  {'course_id': '012176',
#   'subject': 'CM',
#   'catalog_number': '740',
#   'title': 'Fundamentals of Optimization',
#   'prerequisites_parsed': []},
#  {'course_id': '000724',
#   'subject': 'CM',
#   'catalog_number': '750',
#   'title': 'Numerical Solution of Partial Differential Equations',
#   'prerequisites_parsed': []},
#  {'course_id': '003090',
#   'subject': 'CM',
#   'catalog_number': '761',
#   'title': 'Computational Inference',
#   'prerequisites_parsed': []},
#  {'course_id': '012612',
#   'subject': 'CM',
#   'catalog_number': '762',
#   'title': 'Data Visualization',
#   'prerequisites_parsed': []},
#  {'course_id': '003091',
#   'subject': 'CM',
#   'catalog_number': '763',
#   'title': 'Statistical Learning - Classification',
#   'prerequisites_parsed': []},
#  {'course_id': '003092',
#   'subject': 'CM',
#   'catalog_number': '764',
#   'title': 'Statistical Learning - Function Estimation',
#   'prerequisites_parsed': []},
#  {'course_id': '012289',
#   'subject': 'CMW',
#   'catalog_number': '201',
#   'title': 'Worship Practicum 1',
#   'prerequisites_parsed': []},
#  {'course_id': '012290',
#   'subject': 'CMW',
#   'catalog_number': '202',
#   'title': 'Worship Practicum 2',
#   'prerequisites_parsed': []},
#  {'course_id': '007051',
#   'subject': 'CMW',
#   'catalog_number': '363',
#   'title': 'The Christian Hymn',
#   'prerequisites_parsed': []},
#  {'course_id': '007052',
#   'subject': 'CMW',
#   'catalog_number': '364',
#   'title': 'Worship and its Music',
#   'prerequisites_parsed': []},
#  {'course_id': '013525',
#   'subject': 'CMW',
#   'catalog_number': '390',
#   'title': 'Special Topics in Church Music and Worship',
#   'prerequisites_parsed': []},
#  {'course_id': '003887',
#   'subject': 'CO',
#   'catalog_number': '227',
#   'title': 'Introduction to Optimization (Non-Specialist Level)',
#   'prerequisites_parsed': [1,
#    'MATH106',
#    'MATH114',
#    'MATH115',
#    'MATH136',
#    'MATH146']},
#  {'course_id': '003895',
#   'subject': 'CO',
#   'catalog_number': '250',
#   'title': 'Introduction to Optimization',
#   'prerequisites_parsed': [1, 'MATH106', 'MATH115', 'MATH136', 'MATH146']},
#  {'course_id': '003897',
#   'subject': 'CO',
#   'catalog_number': '255',
#   'title': 'Introduction to Optimization (Advanced Level)',
#   'prerequisites_parsed': [[1, 'MATH235', 'MATH245'],
#    [1, 'MATH237', 'MATH247']]},
#  {'course_id': '003890',
#   'subject': 'CO',
#   'catalog_number': '327',
#   'title': 'Deterministic OR Models (Non-Specialist Level)',
#   'prerequisites_parsed': [1, 'CO227', 'CO250', 'CO255', 'CO352']},
#  {'course_id': '003891',
#   'subject': 'CO',
#   'catalog_number': '330',
#   'title': 'Combinatorial Enumeration',
#   'prerequisites_parsed': [1, 'MATH239', 'MATH249']},
#  {'course_id': '003892',
#   'subject': 'CO',
#   'catalog_number': '331',
#   'title': 'Coding Theory',
#   'prerequisites_parsed': [1, 'MATH225', 'MATH235', 'MATH245']},
#  {'course_id': '003893',
#   'subject': 'CO',
#   'catalog_number': '342',
#   'title': 'Introduction to Graph Theory',
#   'prerequisites_parsed': [1, 'MATH239', 'MATH249']},
#  {'course_id': '003896',
#   'subject': 'CO',
#   'catalog_number': '351',
#   'title': 'Network Flow Theory',
#   'prerequisites_parsed': [1, 'CO250', 'CO255', 'CO352']},
#  {'course_id': '011442',
#   'subject': 'CO',
#   'catalog_number': '353',
#   'title': 'Computational Discrete Optimization',
#   'prerequisites_parsed': [1, 'CO250', 'CO255', 'CO352']},
#  {'course_id': '003898',
#   'subject': 'CO',
#   'catalog_number': '367',
#   'title': 'Nonlinear Optimization',
#   'prerequisites_parsed': [[1, 'CO250', 'CO255', 'CO352'],
#    [1, 'MATH128', 'MATH138', 'MATH148']]},
#  {'course_id': '003899',
#   'subject': 'CO',
#   'catalog_number': '370',
#   'title': 'Deterministic OR Models',
#   'prerequisites_parsed': [1, 'CO250', 'CO255', 'CO352']},
#  {'course_id': '011736',
#   'subject': 'CO',
#   'catalog_number': '372',
#   'title': 'Portfolio Optimization Models',
#   'prerequisites_parsed': [[1,
#     [1, 'AFM272', 'ACTSC291'],
#     'ACTSC371',
#     'BUS393W',
#     'ECON371'],
#    [1, 'CO227', 'CO250', 'CO255', 'CO352']]},
#  {'course_id': '003901',
#   'subject': 'CO',
#   'catalog_number': '380',
#   'title': 'Mathematical Discovery and Invention',
#   'prerequisites_parsed': [[1, 'MATH135', 'MATH145'],
#    [1, 'MATH106', 'MATH136', 'MATH146'],
#    [1, 'MATH138', 'MATH148']]},
#  {'course_id': '003902',
#   'subject': 'CO',
#   'catalog_number': '430',
#   'title': 'Algebraic Enumeration',
#   'prerequisites_parsed': ['CO330']},
#  {'course_id': '003903',
#   'subject': 'CO',
#   'catalog_number': '434',
#   'title': 'Combinatorial Designs',
#   'prerequisites_parsed': [1, 'PMATH336', 'PMATH346', 'PMATH347']},
#  {'course_id': '003906',
#   'subject': 'CO',
#   'catalog_number': '439',
#   'title': 'Topics in Combinatorics',
#   'prerequisites_parsed': ''},
#  {'course_id': '003907',
#   'subject': 'CO',
#   'catalog_number': '440',
#   'title': 'Topics in Graph Theory',
#   'prerequisites_parsed': ['CO342']},
#  {'course_id': '003908',
#   'subject': 'CO',
#   'catalog_number': '442',
#   'title': 'Graph Theory',
#   'prerequisites_parsed': ['CO342', [1, 'MATH235', 'MATH245']]},
#  {'course_id': '003909',
#   'subject': 'CO',
#   'catalog_number': '444',
#   'title': 'Algebraic Graph Theory',
#   'prerequisites_parsed': [[1, 'MATH239', 'MATH249'],
#    [1, 'PMATH336', 'PMATH346', 'PMATH347']]},
#  {'course_id': '013337',
#   'subject': 'CO',
#   'catalog_number': '446',
#   'title': 'Matroid Theory',
#   'prerequisites_parsed': ['CO342']},
#  {'course_id': '003910',
#   'subject': 'CO',
#   'catalog_number': '450',
#   'title': 'Combinatorial Optimization',
#   'prerequisites_parsed': [1, 'CO255', 'CO351']},
#  {'course_id': '003911',
#   'subject': 'CO',
#   'catalog_number': '452',
#   'title': 'Integer Programming',
#   'prerequisites_parsed': [1, 'CO255', 'CO351']},
#  {'course_id': '003912',
#   'subject': 'CO',
#   'catalog_number': '453',
#   'title': 'Network Design',
#   'prerequisites_parsed': [[1, 'MATH229', 'MATH239', 'MATH249'],
#    [1, 'CO227', 'CO250', 'CO255', 'CO352']]},
#  {'course_id': '003913',
#   'subject': 'CO',
#   'catalog_number': '454',
#   'title': 'Scheduling',
#   'prerequisites_parsed': [[1, 'MATH229', 'MATH239', 'MATH249'],
#    [1, 'CO227', 'CO250', 'CO255', 'CO352']]},
#  {'course_id': '003914',
#   'subject': 'CO',
#   'catalog_number': '456',
#   'title': 'Introduction to Game Theory',
#   'prerequisites_parsed': [[1, 'MATH229', 'MATH239', 'MATH249'],
#    [1, 'CO227', 'CO250', 'CO255', 'CO352']]},
#  {'course_id': '010046',
#   'subject': 'CO',
#   'catalog_number': '459',
#   'title': 'Topics in Optimization',
#   'prerequisites_parsed': ''},
#  {'course_id': '010047',
#   'subject': 'CO',
#   'catalog_number': '463',
#   'title': 'Convex Optimization and Analysis',
#   'prerequisites_parsed': [[1, 'CO255', 'CO367'],
#    [1, [1, 'AMATH331', 'PMATH331'], 'PMATH351']]},
#  {'course_id': '015890',
#   'subject': 'KPE',
#   'catalog_number': '217W',
#   'title': 'Physical Activity, Sport and the Social Sciences (WLU)',
#   'prerequisites_parsed': []},
#  {'course_id': '014722',
#   'subject': 'COGSCI',
#   'catalog_number': '300',
#   'title': 'Intelligence in Machines, Humans, and Other Animals',
#   'prerequisites_parsed': [1, 'PHIL256', 'PSYCH256']},
#  {'course_id': '003917',
#   'subject': 'CO',
#   'catalog_number': '466',
#   'title': 'Continuous Optimization',
#   'prerequisites_parsed': [1, ['CO367', [1, 'CO250', 'CO352']], 'CO255']},
#  {'course_id': '011364',
#   'subject': 'CO',
#   'catalog_number': '471',
#   'title': 'Semidefinite Optimization',
#   'prerequisites_parsed': [[1, 'MATH239', 'MATH249'],
#    [1, [1, 'AMATH331', 'PMATH331'], 'PMATH351'],
#    'CO255']},
#  {'course_id': '003918',
#   'subject': 'CO',
#   'catalog_number': '480',
#   'title': 'History of Mathematics',
#   'prerequisites_parsed': [[1, 'MATH135', 'MATH145'],
#    [1, 'MATH106', 'MATH136', 'MATH146'],
#    [1, 'MATH138', 'MATH148']]},
#  {'course_id': '011497',
#   'subject': 'CO',
#   'catalog_number': '481',
#   'title': 'Introduction to Quantum Information Processing',
#   'prerequisites_parsed': [1, 'MATH114', 'MATH115', 'MATH235', 'MATH245']},
#  {'course_id': '010137',
#   'subject': 'CO',
#   'catalog_number': '485',
#   'title': 'The Mathematics of Public-Key Cryptography',
#   'prerequisites_parsed': [1,
#    'PMATH334',
#    'PMATH336',
#    'PMATH345',
#    'PMATH346',
#    'PMATH347']},
#  {'course_id': '010136',
#   'subject': 'CO',
#   'catalog_number': '487',
#   'title': 'Applied Cryptography',
#   'prerequisites_parsed': [[1, 'MATH135', 'MATH145'],
#    [1, 'STAT206', 'STAT220', 'STAT230', 'STAT240']]},
#  {'course_id': '003920',
#   'subject': 'CO',
#   'catalog_number': '499',
#   'title': 'Reading in Combinatorics and Optimization',
#   'prerequisites_parsed': ''},
#  {'course_id': '012175',
#   'subject': 'CO',
#   'catalog_number': '601',
#   'title': 'Fundamentals of Enumerative Combinatorics',
#   'prerequisites_parsed': []},
#  {'course_id': '012176',
#   'subject': 'CO',
#   'catalog_number': '602',
#   'title': 'Fundamentals of Optimization',
#   'prerequisites_parsed': []},
#  {'course_id': '000232',
#   'subject': 'CO',
#   'catalog_number': '630',
#   'title': 'Algebraic Enumeration',
#   'prerequisites_parsed': []},
#  {'course_id': '014211',
#   'subject': 'CO',
#   'catalog_number': '631',
#   'title': 'Symmetric Functions',
#   'prerequisites_parsed': []},
#  {'course_id': '000233',
#   'subject': 'CO',
#   'catalog_number': '634',
#   'title': 'Combinatorial Designs',
#   'prerequisites_parsed': []},
#  {'course_id': '010470',
#   'subject': 'CO',
#   'catalog_number': '639',
#   'title': 'Topics in Combinatorics',
#   'prerequisites_parsed': []},
#  {'course_id': '000239',
#   'subject': 'CO',
#   'catalog_number': '640',
#   'title': 'Topics in Graph Theory',
#   'prerequisites_parsed': []},
#  {'course_id': '000245',
#   'subject': 'CO',
#   'catalog_number': '642',
#   'title': 'Graph Theory',
#   'prerequisites_parsed': []},
#  {'course_id': '000246',
#   'subject': 'CO',
#   'catalog_number': '644',
#   'title': 'Algebraic Graph Theory',
#   'prerequisites_parsed': []},
#  {'course_id': '013351',
#   'subject': 'CO',
#   'catalog_number': '646',
#   'title': 'Matroid Theory',
#   'prerequisites_parsed': []},
#  {'course_id': '000247',
#   'subject': 'CO',
#   'catalog_number': '650',
#   'title': 'Combinatorial Optimization',
#   'prerequisites_parsed': []},
#  {'course_id': '000248',
#   'subject': 'CO',
#   'catalog_number': '652',
#   'title': 'Integer Programming',
#   'prerequisites_parsed': []},
#  {'course_id': '000250',
#   'subject': 'CO',
#   'catalog_number': '663',
#   'title': 'Convex Optimization and  Analysis',
#   'prerequisites_parsed': []},
#  ...]

# %%
def formatCourseName(s):
    """
    CS135 -> CS 135
    """
    split_idx = 0
    for i in range(len(s)):
        if s[i].isdigit():
            break
        split_idx += 1
    return s[:split_idx] + " " + s[split_idx:]

assert formatCourseName("CS135") == "CS 135"
assert formatCourseName("MECH223") == "MECH 223"

# %%
def flattenORPrereqs(lst):
    # I think I did too much racket programming guys... #foldr
    
    if len(lst) == 0:
        return []
    elif lst[0] == 1:
        return [1] + flattenORPrereqs(lst[1:])
    elif isinstance(lst[0], list) and lst[0][0] == 1:
        return flattenORPrereqs(lst[0][1:]) + flattenORPrereqs(lst[1:])
    elif isinstance(lst[0], list):
        return flattenORPrereqs(lst[0]) + flattenORPrereqs(lst[1:])
    else:
        return [lst[0]] + flattenORPrereqs(lst[1:])
            
    
bad_input = [1, [1, 'AFM372', 'ACTSC391'], ['ACTSC231', 'ACTSC371'], 'ACTSC231BUS']
expected = [1, 'AFM372', 'ACTSC391', 'ACTSC231', 'ACTSC371', 'ACTSC231BUS']
assert flattenORPrereqs(bad_input) == expected

# %%
from collections import defaultdict

prereq_mapping = defaultdict(list)

for course in courses:
    course_name = course['subject'] + " " + course['catalog_number']
    prereqs = course['prerequisites_parsed']
    if prereqs is None:
        continue
    if len(prereqs) > 0 and isinstance(prereqs[0], int):
        prereqs = [prereqs]
    
    for pre in prereqs:
        if isinstance(pre, list) and len(pre) > 1:
            pre = flattenORPrereqs(pre)
            orCount = pre[0]
            pre[0] = 1 # Some, like FRENCH, will have 2. Just make it one for simplicity...
            # Make a course group
            course_group = []
            for c in pre[1:]:
                g = formatCourseName(c)
                course_group.append(g)
            course_group = list(map(formatCourseName, pre[1:]))
            course_group = list(filter(lambda c: c in set_course, course_group))
            if len(course_group) == 0:
                continue
            prereq_mapping[course_name].append((orCount, course_group))
        else:
            # A single required course
            try:
                c = formatCourseName(pre)
                if c in set_course:
                    prereq_mapping[course_name].append((1, [c])) # 1 OR count -> That course is mandatory
            except:
                # Probably an error with the UW API
                continue
        
        ### DEBUG ###
        #if len(prereq_mapping[course_id]) > 0:
        #    print(prereq_mapping[course_id][-1])

# %%
### At this point each course has its prereqs parsed. (multiple coureses in a course group -> OR)
# prereq_mapping['CS 350']

# %%
# This is just a sanity check to make sure all the courses and their prereqs are in `set_course`
for k, v in prereq_mapping.items():
    if k not in set_course:
        print(k, v)
        raise Exception("{} is not in `set_course`, make some deletions!")
        break
    for l in v:
        for p in l[1]:
            if p not in set_course:
                raise Exception("{} is not in `set_course`, make some deletions!".format(p))

# %%
# Create a course group
courseGroupQuery = """INSERT INTO courseGroup (quantity) VALUES ({});"""
courseGroupMemberQuery = """
WITH groupID as(
    SELECT currval(pg_get_serial_sequence('courseGroup', 'groupid')) as v
)
INSERT INTO courseGroupMember (courseCode, courseGroupID) VALUES ('{}', (SELECT v from groupID));"""

# Add a course group as a prereq
addPrereqQuery = """
WITH groupID as(
    SELECT currval(pg_get_serial_sequence('courseGroup', 'groupid')) as v
)
INSERT INTO prerequisite (courseCode, prereqCourseGroupID) VALUES ('{}', (SELECT v from groupID));
"""

# %%
stmts_prerequisite = []

for course, prereqs in prereq_mapping.items():
    
    # Comments for the insert file
    stmts_prerequisite.append( "-" * 100)
    stmts_prerequisite.append( "--- {} --> {}".format(course, prereqs))
    stmts_prerequisite.append( "-" * 100)
    
    for num_required_from_or, or_prereq_lst in prereqs:
 
        stmts_prerequisite.append( courseGroupQuery.format( num_required_from_or ) )
            
        or_prereq_lst = list(set(or_prereq_lst))
        for p in or_prereq_lst:
            stmts_prerequisite.append( courseGroupMemberQuery.format(p) )
        
        stmts_prerequisite.append( addPrereqQuery.format(course))

# %% [markdown]
# ### Output to Files

# %%
with open('insert_1_faculty.sql', 'w+') as f:
    for line in stmts_faculty:
        f.write(line + '\n')

# %%
with open('insert_2_subject.sql', 'w+') as f:
    for line in stmts_subject:
        f.write(line + '\n')

# %%
with open('insert_3_course.sql', 'w+') as f:
    for line in stmts_course:
        f.write(line + '\n')

# %%
with open('insert_4_term.sql', 'w+') as f:
    for line in stmts_term:
        f.write(line + '\n')

# %%
with open('insert_5_courseOffering.sql', 'w+') as f:
    for line in stmts_courseOffering:
        f.write(line + '\n')

# %%
with open('insert_6_prerequisite.sql', 'w+') as f:
    for line in stmts_prerequisite:
        f.write(line + "\n")

# %% [markdown]
# ### Export Course.txt

# %%
with open('course.txt', 'w+') as f:
    for line in set_course:
        f.write(line + '\n')
